# %% [markdown]
# # COGS 108 - Final Project

# %% [markdown]
# # Overview

# %% [markdown]
# For this project we wanted to focus on police stops related with intoxicating substances (drugs and alcohol) and physical altercations. A large portion of our project outside the analysis was computing distances between these types of police stops and types of businesses. For our analysis we used  exploratory data analysis and the statistical modeling method ANOVA(analysis of variance) which is an extension of the independent T test. We used these methods to compare the average number of police stops within a specific radius from the business and defined this radius to be 500 meters which we believed was close to one blocks.

# %% [markdown]
# # Names
#
# - Les Wang
# - Sebastian Troncoso
# - Tamuz Hod
# - Josh Freilich
# - Baizhou Xu

# %% [markdown]
# # Group Members IDs
#
# - A12985002
# - A14217903
# - A15230380
# - A13837230
# - U08254404

# %% [markdown]
# # Research Question

# %% [markdown]
# Our research question is "How does the type of business affect the type of police stops around different business types?". For our first analysis, the effect of the business is measured by determining the three closest stops that occur at the business. These three stops are considered to be directly influenced by the type of business in this analysis. The three closest stops were chosen in order to prevent variability and outliers as well as providing a larger picture for each business type. For our second analysis, the measure of how much a business affects the type of police stops is defined by the number of police stops that occur within a 0.5km radius (Note: the distance can be changed within the code to determine the correlation at different distances). 0.5km was chosen due to 0.5km being about the size of one block.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Through an interactive map provided by the San Diego Union Tribune, we searched for battery, alcohol, drug related crimes as they were the most frequent crimes reported <b>(1)</b>. We found that these three crimes had a strong connection to particular communities, such as Pacific Beach, Downtown San Diego, and Hillcrest. We wanted to investigate why there were high concentration of crime reports in this community, and found a l 2014 report from the University of Virginia explaining how pawn shops encouraged theft-related crimes. According to the report, experts explained that pawn shops in the premises increases the likelihood for a theft-related crime in the community since people in poverty see pawn shops as stores that help facilitate a market for stolen items <b>(2)</b>.  Police authorities have noticed the trend and began to work closely with pawns shop owners to arrest criminals selling stolen goods.
#
# In fact, the more we searched location-crime related reports, the more we began to question whether or not businesses could attract crimes into the community. Our curiosity led us to a study done by the Center of Disease and Control Prevention which investigated tobacco and alcohol shops indirectly promoting crime in the Los Angeles area. According to the report, South Central Los Angeles had a significant amount of violent and property crime within a measured distance from these types of businesses <b>(3)</b>. Furthermore, another report performed in the Sacramento area explained that residents living close by alcohol stores had a stronger tendency to return back to purchase more alcohol, which led those individuals become arrested due public intoxications and disruptive behavior <b>(4)</b>.
#  For this project, we decided to investigate battery and alcohol related crimes due to the frequency of reported cases, and research possible types of businesses attracting  these crime in the San Diego area.
#
# References:
# - 1) San Diego Historical Crime Actuals
# https://www.sandiego.gov/sites/default/files/ucr1950to2018.pdf
# - 2)“Interactive Map of Crimes in San Diego”
# https://www.sandiegouniontribune.com/news/public-safety/story/2019-06-05/interactive-map-shows-crimes-around-san-diego-20190604
# - 3)“Type of business attracting crime - Pawn Shops and Marijuana Stores”
# https://archive.attn.com/stories/3382/which-businesses-attract-crime
# - 4)“Tobacco and Alcohol promote violent and property crime”
# https://www.sciencedirect.com/science/article/pii/S0091743517305078
# - 5)“Sacramento police officers”
# http://www.colgate.edu/portaldata/imagegallerywww/2050/ImageGallery/teh_jobmktpaper.pdf

# %% [markdown]
# # Hypothesis

# %% [markdown]
# From our background research we predict that a correlation exists between stops relating to alcohol, drugs, and physical altercations and the type of business. We believe this outcome will be correct based on previous research done on the correlation of alcohol and arrests. For example, we believe that police tend to frequent areas that have a larger number of potentially dangerous conflicts, which are frequent at businesses that provide alcohol as seen above in our research. Because more police activity exists in these areas, the likelihood of being stopped by police in these areas are higher.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# <b>Dataset: Ripa police stop data - reason for stop</b>
# - Link: https://data.sandiego.gov/datasets/police-ripa-stop-reason/
# - Number of observations: 91962
# - Description: The data collection of San Diego Police Stops was due to the Racial and Identity Profiling Act of 2015 or RIPA. The dataset contains information on the reason for the police stop as well as to the information for each stop. This is further broken down into stop_id and pid, indicating each stop and each person uniquely per stop (as there can be multiple people involved in a single stop).
#
# <b>Dataset: Ripa police stop data - stop details</b>
# - Link: https://data.sandiego.gov/datasets/police-ripa-stop-reason/
# - Number of observations: 89485
# - Description: The data collection of San Diego Police Stops was due to the Racial and Identity Profiling Act of 2015 or RIPA. The dataset contains information on multiple aspects of the stop, but in regards to this project, mainly stop location. The datasets also included the same pid and stop_id used above in the Ripa police stop data - reason for stop.
#
# <b> Note about number of observations of RIPA datasets: </b> After data cleaning, and only using our desired types of crimes, the total number of crime (combining RIPA datasets) data points is 2597.
#
# <b>Dataset: San Diego Department of Treasury’s Active Business Listings</b>
# - Link: https://www.sandiego.gov/treasurer/taxesfees/btax/nblactive
# - Number of observations: 39195 After data cleaning, the number of observations for this dataset is 26058 (See Data Cleaning section for more detailed information).
# - Description: This dataset contains information on all businesses who have registered for a City of San Diego Business Tax Certificate. For this project, we mainly looked at business activity and location. We further condensed the business activities to more general labels. This was done in order to make each business activity have enough data points to make significant analysis.
# - <b>Note: </b>This dataset was the combination of two datasets as they were split alphabetically between A - K and L - Z but they will be considered one dataset as they contain the
#
#
#
# <b>Note on how RIPA Datasets were used together: </b>
# Each of the RIPA datasets contained pid and stop_id columns. These columns were concatenated together with an underscore in between to create a unique identifier, named “uid”, which was used to merge the two RIPA datasets.
#
# <b>Note on how RIPA Datasets and Business Datasets were used together: </b>
# 	We found the latitude and longitude data of the crime committed from its location metadata. Using the latitude and longitude data of the crime, we researched whether or not there was a correlation between the type of business, labeled “ACTIVITY DESC” in the business dataset, and the frequency of nearby crimes.

# %% [markdown]
# # Setup

# %%
# Imports needed for the code to run 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import geopy.distance
import sklearn
from statsmodels.formula.api import ols
import statsmodels.api as sm
import statsmodels.stats.multicomp

from sklearn.neighbors import kneighbors_graph
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, precision_recall_fscore_support

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# In this step the datasets are imported and a universal identifier (uid) is created from the stop_id and pid columns.

# %%
# Creating data tables from the RIPA datasets
reason_df = pd.read_csv("Datasets/reason_for_stop.csv")
details_df = pd.read_csv("Datasets/basic_details.csv",low_memory=False)

# Adding a unique identifier column to combine the stop_id and pid (person id) 
# This is done to be able to combine the two RIPA datasets into one
reason_df['uid'] = reason_df.stop_id.astype(str).str.cat(reason_df.pid.astype(str), sep='_')
details_df['uid'] = details_df.stop_id.astype(str).str.cat(details_df.pid.astype(str), sep='_')

# %% [markdown]
# Next the datasets are merged on the <b>uid</b> and all columns that are not relevant to this analysis are dropped.

# %%
# Merging two RIPA datasets into one based on uid
totalStop_df = pd.merge(reason_df, details_df, on='uid')

# Dropping unused columns from dataset
totalStop_df = totalStop_df.drop(["agency", "beat", "beat_name", "isschool","school_name", "isstudent"], axis=1)

# %% [markdown]
# To create the business dataframe, we simply concatenated the two business csv files that were separated in to (A-L) and (L-Z)

# %%
# Combining two dataframes that comprise businesss from A-L and L-Z
dfA_L = pd.read_csv('Data/tr_active1.csv')
dfL_Z = pd.read_csv('Data/tr_active2.csv')
df_business = pd.concat([dfA_L,dfL_Z])

# %% [markdown]
# ###### This section will focus on how we extracted the address information from this df and the use of the US cencus georecorder tool.

# %% [markdown]
# Step 1)
# Get the address infromation from the data sets so it can be used in the US census geocoder tool.
#
# The US census geocoder is accepts csv sheets of up to 10,000 lines where each line is formated in the follwing way:
# "street number street name, City, State, "
# ex:
# "4800 NIAGARA AVE, SAN DIEGO, CA,"

# %%
df_business.head()
# Out:
#    BUSINESS ACCT#               DBA NAME OWNERSHIP TYPE  \
# 0      1981012901        #1 FIFTH AVENUE           CORP
# 1      2019005727  #WHO DO U THINK U ARE           SOLE
# 2      2010034224        % NATURAL GOMEZ           SOLE
# 3      2015046247    & SALLY J FERNANDEZ           SOLE
# 4      2007016185            +A PARTNERS           CORP
#
#                        ADDRESS       CITY         ZIP STATE  BUSINESS PHONE  \
# 0                3845 05TH AVE  SAN DIEGO  92103-3140    CA             NaN
# 1                  5754 ELK ST  SAN DIEGO  92114-4025    CA  (619) 362-0605
# 2               4356 POPLAR ST  SAN DIEGO  92105-4657    CA  (619) 417-0105
# 3  17471 PLAZA CERADO SUITE 98  SAN DIEGO  92128-2285    CA             NaN
# 4               3916 NORMAL ST  SAN DIEGO  92103-3413    CA  (619) 294-4477
#
#           OWNER NAME CREATION DT    START DT      EXP DT   NAICS  \
# 0        PUBWAY CORP  12/09/1981  12/09/1981  11/30/2019     722
# 1      KIESHA MILLER  04/02/2019  04/08/2019  04/30/2020    5141
# 2        JUANA GOMEZ  11/12/2010  11/12/2010  11/30/2019  446199
# 3  JAIME V FERNANDEZ  10/29/2015  01/01/2014  12/31/2019  541219
# 4        +A PARTNERS  07/11/2007  07/01/2004  06/30/2019     531
#
#                              ACTIVITY DESC
# 0          FOOD SERVICES & DRINKING PLACES
# 1                     INFORMATION SERVICES
# 2  ALL OTHER HEALTH & PERSONAL CARE STORES
# 3                OTHER ACCOUNTING SERVICES
# 4                              REAL ESTATE

# %% [markdown]
# We discovered that the CITY coulmn was "SAN DIEGO" even when address were located in "La Jolla" or "El Cajon"
# So we tried each address for both of these city names as well

# %%
# Gets the location metadata from the business dataset and formats it
def generateCSVadresses() :
    for j in range(0,18):
        f = open("business_loc"+str(j)+".csv","w+")
        print(j)
        for i in range(3333*j, 3333 * (j+1)):
            if(i >= len(df_business) -1):
                break
            row = df_business.iloc[i]
            try:
                f.write(str(i) + '001,' + row['ADDRESS'] + ',' + row['CITY'] + ',CA,\n')
                if(row['CITY'] == "SAN DIEGO") : 
                    f.write(str(i) + '002,' + row['ADDRESS'] + ',' + 'La Jolla' + ',CA,\n')
                    f.write(str(i) + '003,' + row['ADDRESS'] + ',' + 'El Cajon' + ',CA,\n')
            except:
                print("Error on line ", i)
        f.close()
# generateCSVadresses()

# %% [markdown]
# We then manually inputted this into the georecorder (https://geocoding.geo.census.gov/geocoder/locations/addressbatch?form)
# as this was to be done only once.

# %% [markdown]
# We than combined the csv files using the command line and uploaded the result to our data folder

# %%
# Input
data_file = "Data/GeoBusinessData/geoBusinessData.csv"

# Generate column names
column_names = ['uid', 'address', 'match?', 'exact?', 'full_address', 'lon,lat', 'remove', 'LR']
geoBusiness_df = pd.read_csv(data_file, header=None, names=column_names)
geoBusiness_df.count()
# Out:
# uid             170370
# address         170370
# match?          170370
# exact?           51353
# full_address     51353
# lon,lat          51353
# remove           51353
# LR               51353
# dtype: int64

# %% [markdown]
# We procceded to drop any row that was not a match
# and get back the orginal index location

# %%
geoBusiness_df = geoBusiness_df.dropna()

#Remove previous formatting in order to obtain original uid
def shorten(uid) :
    return int(str(uid)[0:len(str(uid)) - 3])
geoBusiness_df['uid'] = geoBusiness_df['uid'].apply(shorten)

geoBusiness_df = geoBusiness_df.set_index('uid')
geoBusiness_df = geoBusiness_df.sort_index()
geoBusiness_df.head()
# Out:
#                                           address match?     exact?  \
# uid
# 1                    5754 ELK ST, SAN DIEGO, CA,   Match      Exact
# 2                 4356 POPLAR ST, SAN DIEGO, CA,   Match      Exact
# 3    17471 PLAZA CERADO SUITE 98, SAN DIEGO, CA,   Match  Non_Exact
# 4                 3916 NORMAL ST, SAN DIEGO, CA,   Match      Exact
# 5                 5383 AUBURN DR, SAN DIEGO, CA,   Match      Exact
#
#                                full_address               lon,lat  \
# uid
# 1         5754 ELK ST, SAN DIEGO, CA, 92114  -117.07374,32.704464
# 2      4356 POPLAR ST, SAN DIEGO, CA, 92105  -117.10183,32.737766
# 3    17471 PLZ CERADO, SAN DIEGO, CA, 92128  -117.05527,33.028744
# 4      3916 NORMAL ST, SAN DIEGO, CA, 92103  -117.14946,32.749218
# 5      5383 AUBURN DR, SAN DIEGO, CA, 92105  -117.089806,32.73843
#
#           remove LR
# uid
# 1    648577820.0  L
# 2    195347398.0  L
# 3    612877365.0  R
# 4    195342882.0  L
# 5    195350513.0  R

# %% [markdown]
# Since we got the addresses from a concatenated dataframe of the business A_L and L_Z we had to match the index the folowing way:

# %%
dfA_L["lon"] = np.nan
dfA_L["lat"] = np.nan
dfL_Z["lon"] = np.nan
dfL_Z["lat"] = np.nan

# %%
#Corresponds location data to original business
for i in range (0,len(dfA_L)) :
    try :
        loc_lat = geoBusiness_df.loc[i,:]["lon,lat"]
        dfA_L.iat[i, len(dfA_L.columns) - 2] = loc_lat[0:loc_lat.find(',')]
        dfA_L.iat[i, len(dfA_L.columns) - 1] = loc_lat[loc_lat.find(',')+1:]
    except :
        continue

for i in range (0,len(dfL_Z)) :
    try :
        loc_lat = geoBusiness_df.loc[28302 + i,:]["lon,lat"]
        dfL_Z.iat[i, len(dfL_Z.columns) - 2] = loc_lat[0:loc_lat.find(',')]
        dfL_Z.iat[i, len(dfL_Z.columns) - 1] = loc_lat[loc_lat.find(',')+1:]
    except :
        continue

# %% [markdown]
# We than got rid of the businesses from whom we did not find an address and recombined them

# %%
dfA_L.dropna(inplace = True)
dfL_Z.dropna(inplace = True)

business_df = pd.concat([dfA_L, dfL_Z]).reset_index(drop=True)
business_df.head()
# Out:
#    BUSINESS ACCT#               DBA NAME OWNERSHIP TYPE  \
# 0      2019005727  #WHO DO U THINK U ARE           SOLE
# 1      2010034224        % NATURAL GOMEZ           SOLE
# 2      2007016185            +A PARTNERS           CORP
# 3      2016012911    1 ALL EYES AND EARS           SOLE
# 4      2013047218    1 AMERICAN LIVESCAN           CORP
#
#                            ADDRESS       CITY         ZIP STATE  \
# 0                      5754 ELK ST  SAN DIEGO  92114-4025    CA
# 1                   4356 POPLAR ST  SAN DIEGO  92105-4657    CA
# 2                   3916 NORMAL ST  SAN DIEGO  92103-3413    CA
# 3                   5383 AUBURN DR  SAN DIEGO  92105-3624    CA
# 4  3690 MURPHY CANYON RD SUITE 102  SAN DIEGO  92123-4455    CA
#
#    BUSINESS PHONE                 OWNER NAME CREATION DT    START DT  \
# 0  (619) 362-0605              KIESHA MILLER  04/02/2019  04/08/2019
# 1  (619) 417-0105                JUANA GOMEZ  11/12/2010  11/12/2010
# 2  (619) 294-4477                +A PARTNERS  07/11/2007  07/01/2004
# 3  (619) 395-1586           KATRINA GONZALEZ  09/26/2016  10/01/2016
# 4  (858) 874-3119  STONECREST GAS & WASH INC  04/30/2013  01/01/2012
#
#        EXP DT   NAICS                            ACTIVITY DESC         lon  \
# 0  04/30/2020    5141                     INFORMATION SERVICES -117.073740
# 1  11/30/2019  446199  ALL OTHER HEALTH & PERSONAL CARE STORES -117.101830
# 2  06/30/2019     531                              REAL ESTATE -117.149460
# 3  09/30/2019   62419       OTHER INDIVIDUAL & FAMILY SERVICES -117.089806
# 4  12/31/2019  561611                   INVESTIGATION SERVICES -117.116520
#
#          lat
# 0  32.704464
# 1  32.737766
# 2  32.749218
# 3  32.738430
# 4  32.809334

# %% [markdown]
# Finally we got rid of everything that was not business type and the location data

# %%
business_df = business_df[["ACTIVITY DESC", "lon", "lat"]]
business_df.head()
# Out:
#                              ACTIVITY DESC         lon        lat
# 0                     INFORMATION SERVICES -117.073740  32.704464
# 1  ALL OTHER HEALTH & PERSONAL CARE STORES -117.101830  32.737766
# 2                              REAL ESTATE -117.149460  32.749218
# 3       OTHER INDIVIDUAL & FAMILY SERVICES -117.089806  32.738430
# 4                   INVESTIGATION SERVICES -117.116520  32.809334

# %% [markdown]
# The same process was done to the police stop data

# %%
data_file = "Data/GeoCrimeData/reasonable_loc_result.csv"
column_names = ['uid', 'address', 'match?', 'exact?', 'full_address', 'lon,lat', 'remove', 'remove']
geoCrime_reasonable_df = pd.read_csv(data_file, header=None, names=column_names)

geoCrime_reasonable_df = geoCrime_reasonable_df.dropna()
geoCrime_reasonable_df['uid'] = geoCrime_reasonable_df['uid'].apply(shorten)

geoCrime_reasonable_df = geoCrime_reasonable_df.set_index('uid')
geoCrime_reasonable_df = geoCrime_reasonable_df.sort_index()

df_reasonable = pd.read_csv("reasonable.csv", header=0,index_col=0)
# Out:
# C:\Users\Tamuz\Anaconda3\lib\site-packages\pandas\io\parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# C:\Users\Tamuz\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\Tamuz\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (16,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for index, row in geoCrime_reasonable_df.iterrows() :
    loc_lat = row["lon,lat"]
    df_reasonable.at[index, "lon"] = loc_lat[0:loc_lat.find(',')]
    df_reasonable.at[index, "lat"] = loc_lat[loc_lat.find(',')+1:]

# %%
df_reasonable = df_reasonable[["crime_type", "lon", "lat"]]
df_reasonable = df_reasonable.dropna()
df_reasonable.head()
# Out:
#                 crime_type          lon        lat
# stop_id
# 2443             *alcohol*  -116.970985  32.785866
# 2447     *fight / battery*   -117.07028   32.75826
# 2447     *fight / battery*   -117.07028   32.75826
# 2449     *fight / battery*  -117.208534  32.873898
# 2451             *alcohol*  -117.253426  32.793934

# %%
reasonable_crime_csv = df_reasonable.to_csv (r'reasonable_crime.csv', header=True)
business_df_csv = business_df.to_csv (r'business_df.csv', header=True)

# %% [markdown]
# We then combined our business and crime data

# %%
business_df = pd.read_csv("business_df.csv", index_col=0)
business_df = business_df.loc[:, ~business_df.columns.str.contains('^Unnamed')]

reasonable_df = pd.read_csv("reasonable_crime.csv")
reasonable_df = reasonable_df.set_index("stop_id")

reasonable_df.drop_duplicates(keep="last",inplace=True)

alc_fight_df = reasonable_df.loc[reasonable_df["crime_type"].isin(["*fight / battery*", "*alcohol*"])]

# %% [markdown]
# Since the distances we are interested in are all within a relativly small geographic area we used the  Euclidean distance between two points based on the understanding that in distances of less than 5km the error will be minimal (~0.04%)
# http://jonisalonen.com/2014/computing-distance-between-coordinates-can-be-simple-and-fast/

# %%
def getDistance(row,lat0,lon0) :
    deglen = 110.25
    x = row["lat"] - lat0
    y = (row["lon"] - lon0) * math.cos(lat0)
    return deglen * math.sqrt(x*x + y*y)
busi_alc_fight_df = business_df

# %% [markdown]
# This calculation was time consuming so it was done in batches using the library's GIS lab "datacruncher" computer

# %%
'''
binNumber = 100
binSize = int(len(alc_fight_df)/binNumber)

for i in range(0,binNumber) :
    n=0
    print(i)
    for row in alc_fight_df.itertuples() :
        n=n+1
        if(n<i*binSize):
            continue 
        if(n>=(i+1)*binSize) :
            break
        try :
            busi_alc_fight_df[row[0]] = busi_alc_fight_df.apply(getDistanceTo_reasonable,axis=1,args=(row[3],row[2],))
        except :
            print(index1, "Did not work")
    busi_alc_fight_csv = busi_alc_fight_df.to_csv (r'busi_alc_fight_df3.csv', header=True) 
'''
# Out:
# '\nbinNumber = 100\nbinSize = int(len(alc_fight_df)/binNumber)\n\nfor i in range(0,binNumber) :\n    n=0\n    print(i)\n    for row in alc_fight_df.itertuples() :\n        n=n+1\n        if(n<i*binSize):\n            continue \n        if(n>=(i+1)*binSize) :\n            break\n        try :\n            busi_alc_fight_df[row[0]] = busi_alc_fight_df.apply(getDistanceTo_reasonable,axis=1,args=(row[3],row[2],))\n        except :\n            print(index1, "Did not work")\n    busi_alc_fight_csv = busi_alc_fight_df.to_csv (r\'busi_alc_fight_df3.csv\', header=True) \n'

# %% [markdown]
# The next step is to add the type of the crime to the column head

# %%
pred_procesising_df = pd.read_csv("busi_alc_fight_df3.csv", index_col=0)

reasonable_df = pd.read_csv("reasonable_crime.csv", engine = "python")
reasonable_df = reasonable_df.set_index("stop_id")
reasonable_df = reasonable_df.loc[~reasonable_df.index.duplicated(keep='first')]

# %%
business_df = pred_procesising_df.copy(deep=True)


business_df.drop("lat", axis=1, inplace = True)
business_df.drop("lon", axis=1, inplace = True)
business_df.rename({"ACTIVITY DESC" : "ACTIVITY_DESC"},axis=1, inplace = True)

business_df.head()
# Out:
#                              ACTIVITY_DESC      2447       2455       2485  \
# 0                     INFORMATION SERVICES  5.931638  10.826005  12.152264
# 1  ALL OTHER HEALTH & PERSONAL CARE STORES  2.392861   7.206127   8.598698
# 2                              REAL ESTATE  2.214189   5.652816   7.630572
# 3       OTHER INDIVIDUAL & FAMILY SERVICES  2.239962   7.251192   8.483424
# 4                   INVESTIGATION SERVICES  5.748061   3.089895   2.089211
#
#         2532       2577      2578      2603      2681       2708    ...      \
# 0   2.963084  14.701244  5.165864  5.061442  6.966756   2.434433    ...
# 1   3.528617  18.441642  1.577430  2.160008  3.316914   3.580974    ...
# 2   4.199080  19.989504  0.208213  1.116841  2.557939   4.494928    ...
# 3   3.803150  18.474400  1.753749  2.458503  3.219919   3.815571    ...
# 4  10.899886  26.358912  6.745512  7.572055  4.663792  11.175719    ...
#
#       83256     83284      83318      83333     83335     83336      83359  \
# 0  4.872376  5.262967  10.865340   2.703858  5.096691  9.812076   2.731830
# 1  1.129519  1.554527   7.252293   3.374546  1.443737  6.128407   3.270481
# 2  1.086112  0.578970   5.694998   4.162429  0.415001  4.988487   4.044222
# 3  1.148897  1.651299   7.299620   3.633638  1.592499  6.056638   3.533317
# 4  6.776582  6.492860   3.156492  10.856802  6.726134  1.808533  10.738622
#
#        83365      83366      83369
# 0   3.500604   2.727225   0.629066
# 1   5.091399   3.276868   3.174340
# 2   5.770857   4.052822   4.897985
# 3   5.351134   3.539266   3.163615
# 4  12.477863  10.747115  11.016866
#
# [5 rows x 2598 columns]

# %%
alc_fight_df = reasonable_df.loc[reasonable_df["crime_type"].isin(["*fight / battery*", "*alcohol*"])]


def renameCrimeType(id) :
    if(str(id).isnumeric()):
        try :
            return alc_fight_df.loc[int(id)]["crime_type"][1:6] #id + "_" + 
        except :
            pass
    return id


business_df.rename(columns = lambda x: renameCrimeType(x), inplace = True)
business_df.head()
# Out:
#                              ACTIVITY_DESC     fight      fight      alcoh  \
# 0                     INFORMATION SERVICES  5.931638  10.826005  12.152264
# 1  ALL OTHER HEALTH & PERSONAL CARE STORES  2.392861   7.206127   8.598698
# 2                              REAL ESTATE  2.214189   5.652816   7.630572
# 3       OTHER INDIVIDUAL & FAMILY SERVICES  2.239962   7.251192   8.483424
# 4                   INVESTIGATION SERVICES  5.748061   3.089895   2.089211
#
#        fight      alcoh     fight     alcoh     fight      fight    ...      \
# 0   2.963084  14.701244  5.165864  5.061442  6.966756   2.434433    ...
# 1   3.528617  18.441642  1.577430  2.160008  3.316914   3.580974    ...
# 2   4.199080  19.989504  0.208213  1.116841  2.557939   4.494928    ...
# 3   3.803150  18.474400  1.753749  2.458503  3.219919   3.815571    ...
# 4  10.899886  26.358912  6.745512  7.572055  4.663792  11.175719    ...
#
#       fight     alcoh      alcoh      fight     alcoh     fight      fight  \
# 0  4.872376  5.262967  10.865340   2.703858  5.096691  9.812076   2.731830
# 1  1.129519  1.554527   7.252293   3.374546  1.443737  6.128407   3.270481
# 2  1.086112  0.578970   5.694998   4.162429  0.415001  4.988487   4.044222
# 3  1.148897  1.651299   7.299620   3.633638  1.592499  6.056638   3.533317
# 4  6.776582  6.492860   3.156492  10.856802  6.726134  1.808533  10.738622
#
#        fight      alcoh      fight
# 0   3.500604   2.727225   0.629066
# 1   5.091399   3.276868   3.174340
# 2   5.770857   4.052822   4.897985
# 3   5.351134   3.539266   3.163615
# 4  12.477863  10.747115  11.016866
#
# [5 rows x 2598 columns]

# %%
business_df.set_index("ACTIVITY_DESC", inplace = True)

# %% [markdown]
# Here we got rid of every business that did not have at list 100 of the same type. We did this so none of our sample would
# be too small.

# %%
business_df = business_df.groupby(business_df.index).filter(lambda x : len(x)>99)
business_df.index.value_counts()
# Out:
# JANITORIAL SERVICES                              1122
# ALL OTH PROF, SCIENTIFIC & TECHNICAL SERVICES    1060
# ALL OTHER PERSONAL SERVICES                       781
# BUILDING, DEVELOPING & GENERAL CONTRACTING        687
# CONSULTING SERVICES                               686
# BEAUTY SALONS                                     617
# OTHER PERSONAL SERVICES                           612
# FULL-SERVICE RESTAURANTS                          610
# PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES     591
# ALL OTHER SPECIAL TRADE CONTRACTORS               555
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS         475
# OTHER SERVICES TO BUILDINGS & DWELLINGS           450
# MANAGEMENT CONSULTING SERVICES                    438
# LEGAL SERVICES                                    418
# OFFICES OF DENTISTS                               415
# LANDSCAPING SERVICES                              414
# TAXI SERVICE                                      406
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES     370
# OTH PROFESSIONAL/SCIENTIFIC/TECHNICAL SERVICE     364
# PLUMBING, HEATING & AC CONTRACTOR                 362
# OTHER ACTIVITIES RELATED TO REAL ESTATE           358
# ENGINEERING SERVICES                              354
# BEAUTY SHOPS - BOOTH RENTAL                       349
# OFFICES OF REAL ESTATE AGENTS & BROKERS           344
# OFFICES OF PHYSICIANS                             340
# ELECTRICAL CONTRACTORS                            335
# RETAIL SALES VIA INTERNET/WEBSITES                327
# NONSTORE RETAILERS                                314
# OFFICES OF ALL OTH MISC HEALTH PRACTITIONERS      309
# PHOTOGRAPHIC SERVICES                             309
#                                                  ...
# GROCERY STORES                                    132
# GRAPHIC DESIGN SERVICES                           132
# ALL OTHER AUTOMOTIVE R&M                          130
# REAL ESTATE PROPERTY MANAGERS                     127
# REPAIR & MAINTENANCE                              126
# CHILD DAY CARE SERVICES                           125
# OFFICES OF CHIROPRACTORS                          125
# SNACK & NONALCOHOLIC BEVERAGE BARS                123
# EXAM PREPARATION & TUTORING                       122
# MISCELLANEOUS STORE RETAILERS                     118
# PET CARE (EXCEPT VETERINARY) SERVICES             118
# REAL ESTATE                                       118
# OFFICES OF OTHER MENTAL HEALTH PRACTITIONERS      118
# SPORTS & RECREATION INSTRUCTION                   113
# OFFICE ADMINISTRATIVE SERVICES                    113
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M        113
# PAINTING & WALL COVERING CONTRACTORS              112
# INSURANCE AGENCIES & BROKERAGES                   109
# CONSTRUCTION                                      109
# PERSONAL FITNESS TRAINER                          108
# ADVERTISING & RELATED SERVICES                    107
# ALL OTHER MISCELLANEOUS STORE RETAILERS           106
# OFFICES OF PT/OT/SPEECH THERAPY & AUDIOLOGY       105
# SCIENTIFIC R&D SERVICES                           104
# BARBER SHOPS                                      103
# ARCHITECTURAL SERVICES                            102
# BEER, WINE & LIQUOR STORES                        102
# OTHER BUSINESS SERVICES                           102
# WHOLESALE TRADE, NONDURABLE GOODS                 101
# MANAGEMENT OF COMPANIES & ENTERPRISES             101
# Name: ACTIVITY_DESC, Length: 101, dtype: int64

# %%
type_counts = business_df.index.value_counts()
business_df
# Out:
#                                                     fight       fight  \
# ACTIVITY_DESC
# REAL ESTATE                                      2.214189    5.652816
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       6.271044   11.343244
# CONSULTING SERVICES                             22.848677   18.212236
# PHOTOGRAPHIC SERVICES                           19.051506   15.180222
# OTHER SPECIAL TRADE CONTRACTORS                 14.763661   10.561781
# FULL-SERVICE RESTAURANTS                         4.688336    5.485633
# OTHER PERSONAL SERVICES                         22.976500   18.621064
# GRAPHIC DESIGN SERVICES                         37.835405   33.487217
# MARKETING CONSULTING SERVICES                    3.133679    2.767034
# OTHER SERVICES TO BUILDINGS & DWELLINGS          1.977216    4.819555
# FULL-SERVICE RESTAURANTS                         5.139439    9.174811
# CONSULTING SERVICES                             18.125208   13.940400
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        4.245674    2.208126
# REPAIR & MAINTENANCE                             4.335856    1.775250
# ALL OTHER SPECIAL TRADE CONTRACTORS             29.832142   25.862271
# RETAIL SALES VIA INTERNET/WEBSITES              26.019358   22.073273
# OTHER MISCELLANEOUS STORE RETAILERS              4.499280    8.224607
# BEAUTY SALONS                                    3.690096    4.928556
# BUSINESS TAX EXEMPT                             41.189895   37.186575
# CONSULTING SERVICES                              7.839835    3.986740
# OTHER SERVICES TO BUILDINGS & DWELLINGS         49.865990   45.420883
# MASSAGE THERAPY                                  3.312558    2.629758
# PLUMBING, HEATING & AC CONTRACTOR               49.532299   44.969357
# BUILDING, DEVELOPING & GENERAL CONTRACTING     117.244576  111.994075
# ALL OTHER AUTOMOTIVE R&M                        13.981368    9.305610
# OTHER SPECIAL TRADE CONTRACTORS                563.987025  556.322207
# PLUMBING, HEATING & AC CONTRACTOR               85.645832   81.357765
# MANAGEMENT CONSULTING SERVICES                  11.082672    6.573228
# OTHER SERVICES TO BUILDINGS & DWELLINGS          1.432835    5.248093
# NONSTORE RETAILERS                               3.182529    8.446718
# ...                                                   ...         ...
# BEAUTY SALONS                                    2.576600    3.467135
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    8.479336    4.407413
# USED CAR DEALERS                                 7.291792    7.948727
# USED CAR DEALERS                                 7.719172    3.673090
# LEGAL SERVICES                                  22.058268   26.854711
# CONSULTING SERVICES                              4.069923    2.017994
# OFFICES OF LAWYERS                               5.090177    9.028198
# OTHER SERVICES TO BUILDINGS & DWELLINGS          5.094380    5.007941
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       8.254573    4.275179
# BUILDING, DEVELOPING & GENERAL CONTRACTING      37.864401   33.803060
# BUILDING, DEVELOPING & GENERAL CONTRACTING      15.198823   10.685781
# JANITORIAL SERVICES                              2.695004    8.180107
# OTHER PERSONAL SERVICES                          5.553581    2.078953
# TAXI SERVICE                                    28.829921   24.652179
# CONSULTING SERVICES                             17.087289   13.081289
# BEAUTY SHOPS - BOOTH RENTAL                     28.671251   24.679908
# ALL OTHER PERSONAL SERVICES                      0.695499    6.304536
# OTHER PERSONAL SERVICES                          5.039118    9.296752
# USED CAR DEALERS                                 0.577885    6.177960
# USED CAR DEALERS                                 7.032274   11.402323
# TAXI SERVICE                                    18.797997   15.261952
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES         78.683194   74.487580
# OFFICE ADMINISTRATIVE SERVICES                  22.827087   27.603993
# MANAGEMENT CONSULTING SERVICES                   1.243207    5.598498
# TAXI & LIMOUSINE SERVICE                         0.599237    5.906745
# ALL OTHER SPECIAL TRADE CONTRACTORS            100.113021   94.763175
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE   19.346821   15.403149
# OTHER MISCELLANEOUS STORE RETAILERS              8.648730    4.620684
# MANAGEMENT CONSULTING SERVICES                   5.587022    9.419522
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        2.173590    7.639459
#
#                                                     alcoh       fight  \
# ACTIVITY_DESC
# REAL ESTATE                                      7.630572    4.199080
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS      12.407161    3.957984
# CONSULTING SERVICES                             16.863263   27.696200
# PHOTOGRAPHIC SERVICES                           12.965865   24.332703
# OTHER SPECIAL TRADE CONTRACTORS                  8.878976   19.783452
# FULL-SERVICE RESTAURANTS                         8.690619    4.637091
# OTHER PERSONAL SERVICES                         16.959335   27.974584
# GRAPHIC DESIGN SERVICES                         31.740150   42.878854
# MARKETING CONSULTING SERVICES                    4.714245    7.491242
# OTHER SERVICES TO BUILDINGS & DWELLINGS          4.325723    7.933593
# FULL-SERVICE RESTAURANTS                        11.195342    0.649168
# CONSULTING SERVICES                             12.141436   23.193728
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        3.488706    8.986932
# REPAIR & MAINTENANCE                             4.059086    8.665455
# ALL OTHER SPECIAL TRADE CONTRACTORS             23.693551   35.126631
# RETAIL SALES VIA INTERNET/WEBSITES              19.893229   31.309792
# OTHER MISCELLANEOUS STORE RETAILERS             10.386959    1.367641
# BEAUTY SALONS                                    7.824545    4.745398
# BUSINESS TAX EXEMPT                             35.024799   46.503929
# CONSULTING SERVICES                              2.954875   12.783070
# OTHER SERVICES TO BUILDINGS & DWELLINGS         43.741778   54.877797
# MASSAGE THERAPY                                  4.374184    7.846153
# PLUMBING, HEATING & AC CONTRACTOR               43.390825   54.499502
# BUILDING, DEVELOPING & GENERAL CONTRACTING     110.556778  122.510694
# ALL OTHER AUTOMOTIVE R&M                         8.299339   18.726890
# OTHER SPECIAL TRADE CONTRACTORS                554.023948  572.520978
# PLUMBING, HEATING & AC CONTRACTOR               79.506603   90.757403
# MANAGEMENT CONSULTING SERVICES                   5.634233   15.860295
# OTHER SERVICES TO BUILDINGS & DWELLINGS          4.944063    7.447015
# NONSTORE RETAILERS                               9.361979    3.945976
# ...                                                   ...         ...
# BEAUTY SALONS                                    5.555891    6.526845
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    3.436075   13.368098
# USED CAR DEALERS                                 2.755679   13.774309
# USED CAR DEALERS                                 3.070887   12.559162
# LEGAL SERVICES                                  28.017476   17.998231
# CONSULTING SERVICES                              5.047576    7.762994
# OFFICES OF LAWYERS                              11.103984    0.645655
# OTHER SERVICES TO BUILDINGS & DWELLINGS          1.288715   11.094076
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       3.244783   13.172134
# BUILDING, DEVELOPING & GENERAL CONTRACTING      31.727106   43.112020
# BUILDING, DEVELOPING & GENERAL CONTRACTING       9.392502   20.049358
# JANITORIAL SERVICES                              8.311753    5.757614
# OTHER PERSONAL SERVICES                          3.003780   10.260370
# TAXI SERVICE                                    22.745940   33.961162
# CONSULTING SERVICES                             11.074887   22.255326
# BEAUTY SHOPS - BOOTH RENTAL                     22.544557   33.941363
# ALL OTHER PERSONAL SERVICES                      6.718239    5.832013
# OTHER PERSONAL SERVICES                         11.173668    1.014309
# USED CAR DEALERS                                 6.785218    5.596076
# USED CAR DEALERS                                13.229778    2.074683
# TAXI SERVICE                                    12.597693   24.322497
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES         72.538840   83.860419
# OFFICE ADMINISTRATIVE SERVICES                  28.804124   18.689328
# MANAGEMENT CONSULTING SERVICES                   7.026474    4.859565
# TAXI & LIMOUSINE SERVICE                         6.077401    6.426683
# ALL OTHER SPECIAL TRADE CONTRACTORS             93.400037  105.352549
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE   13.278949   24.581725
# OTHER MISCELLANEOUS STORE RETAILERS              3.502074   13.570498
# MANAGEMENT CONSULTING SERVICES                  11.572831    0.142553
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        7.605534    6.155715
#
#                                                     alcoh       fight  \
# ACTIVITY_DESC
# REAL ESTATE                                     19.989504    0.208213
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS      14.430380    5.770936
# CONSULTING SERVICES                             43.768897   23.677675
# PHOTOGRAPHIC SERVICES                           39.685055   20.184036
# OTHER SPECIAL TRADE CONTRACTORS                 35.462242   15.706043
# FULL-SERVICE RESTAURANTS                        21.106841    2.849075
# OTHER PERSONAL SERVICES                         43.736659   23.918728
# GRAPHIC DESIGN SERVICES                         58.605610   38.820874
# MARKETING CONSULTING SERVICES                   23.296344    3.420666
# OTHER SERVICES TO BUILDINGS & DWELLINGS         22.534296    3.860418
# FULL-SERVICE RESTAURANTS                        16.415777    3.628622
# CONSULTING SERVICES                             38.821018   19.110128
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS       24.696779    4.887594
# REPAIR & MAINTENANCE                            24.607450    4.658363
# ALL OTHER SPECIAL TRADE CONTRACTORS             50.458450   30.979531
# RETAIL SALES VIA INTERNET/WEBSITES              46.647087   27.162667
# OTHER MISCELLANEOUS STORE RETAILERS             17.451054    2.785420
# BEAUTY SALONS                                   21.109380    1.975228
# BUSINESS TAX EXEMPT                             61.820297   42.351144
# CONSULTING SERVICES                             28.466463    8.691747
# OTHER SERVICES TO BUILDINGS & DWELLINGS         70.752921   50.828384
# MASSAGE THERAPY                                 23.594918    3.754032
# PLUMBING, HEATING & AC CONTRACTOR               70.582390   50.453390
# BUILDING, DEVELOPING & GENERAL CONTRACTING     140.893929  118.140052
# ALL OTHER AUTOMOTIVE R&M                        34.775726   14.722215
# OTHER SPECIAL TRADE CONTRACTORS                603.864506  565.508092
# PLUMBING, HEATING & AC CONTRACTOR              106.351452   86.689611
# MANAGEMENT CONSULTING SERVICES                  31.788510   11.835131
# OTHER SERVICES TO BUILDINGS & DWELLINGS         21.904587    3.487919
# NONSTORE RETAILERS                              17.470311    3.067138
# ...                                                   ...         ...
# BEAUTY SALONS                                   22.378194    2.479152
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES   29.116849    9.295766
# USED CAR DEALERS                                27.350205    9.533836
# USED CAR DEALERS                                28.334768    8.492432
# LEGAL SERVICES                                   5.544915   21.383956
# CONSULTING SERVICES                             23.925967    3.913964
# OFFICES OF LAWYERS                              16.600667    3.522470
# OTHER SERVICES TO BUILDINGS & DWELLINGS         25.611690    6.866625
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M      28.888323    9.090656
# BUILDING, DEVELOPING & GENERAL CONTRACTING      58.492554   38.985665
# BUILDING, DEVELOPING & GENERAL CONTRACTING      35.972073   16.019897
# JANITORIAL SERVICES                             18.664387    3.719803
# OTHER PERSONAL SERVICES                         26.062634    6.196633
# TAXI SERVICE                                    49.506234   29.871421
# CONSULTING SERVICES                             37.746446   18.139909
# BEAUTY SHOPS - BOOTH RENTAL                     49.300000   29.802998
# ALL OTHER PERSONAL SERVICES                     20.124196    2.429644
# OTHER PERSONAL SERVICES                         16.215465    3.665049
# USED CAR DEALERS                                20.077751    2.125833
# USED CAR DEALERS                                14.062794    5.797448
# TAXI SERVICE                                    39.432507   20.089416
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES         99.318401   79.769346
# OFFICE ADMINISTRATIVE SERVICES                   5.598322   22.127372
# MANAGEMENT CONSULTING SERVICES                  20.166760    0.880783
# TAXI & LIMOUSINE SERVICE                        20.765779    2.758509
# ALL OTHER SPECIAL TRADE CONTRACTORS            123.888505  100.977000
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE   39.988591   20.448570
# OTHER MISCELLANEOUS STORE RETAILERS             29.290489    9.491056
# MANAGEMENT CONSULTING SERVICES                  16.293498    3.992526
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS       19.363808    3.581413
#
#                                                     alcoh       fight  \
# ACTIVITY_DESC
# REAL ESTATE                                      1.116841    2.557939
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       5.809168    7.332937
# CONSULTING SERVICES                             24.260804   21.745125
# PHOTOGRAPHIC SERVICES                           20.949203   18.016843
# OTHER SPECIAL TRADE CONTRACTORS                 16.386638   13.687195
# FULL-SERVICE RESTAURANTS                         1.962849    4.597146
# OTHER PERSONAL SERVICES                         24.565683   21.902724
# GRAPHIC DESIGN SERVICES                         39.467809   36.773869
# MARKETING CONSULTING SERVICES                    4.129261    2.119141
# OTHER SERVICES TO BUILDINGS & DWELLINGS          5.080020    1.233232
# FULL-SERVICE RESTAURANTS                         3.036037    5.964962
# CONSULTING SERVICES                             19.797177   17.059678
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        5.628604    3.139008
# REPAIR & MAINTENANCE                             5.261852    3.251729
# ALL OTHER SPECIAL TRADE CONTRACTORS             31.729679   28.804723
# RETAIL SALES VIA INTERNET/WEBSITES              27.916663   24.990102
# OTHER MISCELLANEOUS STORE RETAILERS              2.070112    5.214198
# BEAUTY SALONS                                    1.470131    3.559025
# BUSINESS TAX EXEMPT                             43.097489   40.166462
# CONSULTING SERVICES                              9.401711    6.741138
# OTHER SERVICES TO BUILDINGS & DWELLINGS         51.452333   48.796284
# MASSAGE THERAPY                                  4.494547    2.251430
# PLUMBING, HEATING & AC CONTRACTOR               51.053348   48.446555
# BUILDING, DEVELOPING & GENERAL CONTRACTING     118.708805  116.032899
# ALL OTHER AUTOMOTIVE R&M                        15.298471   12.864149
# OTHER SPECIAL TRADE CONTRACTORS                566.461653  562.167305
# PLUMBING, HEATING & AC CONTRACTOR               87.349099   84.602104
# MANAGEMENT CONSULTING SERVICES                  12.445180    9.969999
# OTHER SERVICES TO BUILDINGS & DWELLINGS          4.746183    1.025121
# NONSTORE RETAILERS                               3.621197    4.248945
# ...                                                   ...         ...
# BEAUTY SALONS                                    3.168414    1.790774
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    9.976261    7.376357
# USED CAR DEALERS                                10.872070    6.680988
# USED CAR DEALERS                                 9.166382    6.610332
# LEGAL SERVICES                                  21.056834   23.108977
# CONSULTING SERVICES                              4.332742    3.100394
# OFFICES OF LAWYERS                               2.881818    5.888644
# OTHER SERVICES TO BUILDINGS & DWELLINGS          8.019717    4.227939
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       9.784973    7.154150
# BUILDING, DEVELOPING & GENERAL CONTRACTING      39.711515   36.833978
# BUILDING, DEVELOPING & GENERAL CONTRACTING      16.631602   14.097287
# JANITORIAL SERVICES                              4.691680    3.704380
# OTHER PERSONAL SERVICES                          6.873026    4.437781
# TAXI SERVICE                                    30.562451   27.781067
# CONSULTING SERVICES                             18.868588   16.035222
# BEAUTY SHOPS - BOOTH RENTAL                     30.545921   27.640717
# ALL OTHER PERSONAL SERVICES                      3.658139    1.733272
# OTHER PERSONAL SERVICES                          3.204036    5.918333
# USED CAR DEALERS                                 3.353122    1.660828
# USED CAR DEALERS                                 5.296529    7.977983
# TAXI SERVICE                                    20.942585   17.791835
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES         80.455597   77.649649
# OFFICE ADMINISTRATIVE SERVICES                  21.780933   23.877776
# MANAGEMENT CONSULTING SERVICES                   2.115580    1.764309
# TAXI & LIMOUSINE SERVICE                         4.026416    1.278657
# ALL OTHER SPECIAL TRADE CONTRACTORS            101.529463   98.886102
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE   21.195753   18.306333
# OTHER MISCELLANEOUS STORE RETAILERS             10.181567    7.549568
# MANAGEMENT CONSULTING SERVICES                   3.279223    6.375066
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        4.684096    3.118898
#
#                                                     fight       fight  \
# ACTIVITY_DESC
# REAL ESTATE                                      4.494928   15.518233
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       3.434499   20.833999
# CONSULTING SERVICES                             28.073831    7.984916
# PHOTOGRAPHIC SERVICES                           24.623964    4.888771
# OTHER SPECIAL TRADE CONTRACTORS                 20.113148    1.050168
# FULL-SERVICE RESTAURANTS                         5.206716   15.711966
# OTHER PERSONAL SERVICES                         28.319979    8.369535
# GRAPHIC DESIGN SERVICES                         43.224797   23.245498
# MARKETING CONSULTING SERVICES                    7.814903   12.202715
# OTHER SERVICES TO BUILDINGS & DWELLINGS          8.042536   12.772676
# FULL-SERVICE RESTAURANTS                         0.793694   19.209307
# CONSULTING SERVICES                             23.520207    3.714215
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        9.298325   10.736689
# REPAIR & MAINTENANCE                             9.020585   11.004732
# ALL OTHER SPECIAL TRADE CONTRACTORS             35.423844   15.473837
# RETAIL SALES VIA INTERNET/WEBSITES              31.605376   11.689606
# OTHER MISCELLANEOUS STORE RETAILERS              1.760853   18.292926
# BEAUTY SALONS                                    5.232335   15.109328
# BUSINESS TAX EXEMPT                             46.803151   26.792940
# CONSULTING SERVICES                             13.102061    6.963340
# OTHER SERVICES TO BUILDINGS & DWELLINGS         55.237315   35.194287
# MASSAGE THERAPY                                  8.159910   11.864866
# PLUMBING, HEATING & AC CONTRACTOR               54.874169   34.736892
# BUILDING, DEVELOPING & GENERAL CONTRACTING     122.970781  101.215765
# ALL OTHER AUTOMOTIVE R&M                        19.103234    1.036928
# OTHER SPECIAL TRADE CONTRACTORS                573.232636  541.633699
# PLUMBING, HEATING & AC CONTRACTOR               91.096879   71.122042
# MANAGEMENT CONSULTING SERVICES                  16.220166    3.846253
# OTHER SERVICES TO BUILDINGS & DWELLINGS          7.526105   13.411564
# NONSTORE RETAILERS                               3.756062   17.766819
# ...                                                   ...         ...
# BEAUTY SALONS                                    6.856155   13.157198
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES   13.698595    6.356391
# USED CAR DEALERS                                13.781193   10.007338
# USED CAR DEALERS                                12.892338    7.150602
# LEGAL SERVICES                                  17.529313   36.460019
# CONSULTING SERVICES                              8.164804   11.933391
# OFFICES OF LAWYERS                               0.939961   19.082941
# OTHER SERVICES TO BUILDINGS & DWELLINGS         11.221092    9.944913
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M      13.497170    6.563320
# BUILDING, DEVELOPING & GENERAL CONTRACTING      43.419853   23.454170
# BUILDING, DEVELOPING & GENERAL CONTRACTING      20.410254    0.711171
# JANITORIAL SERVICES                              5.579333   16.838386
# OTHER PERSONAL SERVICES                         10.592884    9.434020
# TAXI SERVICE                                    34.285158   14.358859
# CONSULTING SERVICES                             22.563110    2.924600
# BEAUTY SHOPS - BOOTH RENTAL                     34.241719   14.307335
# ALL OTHER PERSONAL SERVICES                      5.850452   15.144147
# OTHER PERSONAL SERVICES                          0.866766   19.266409
# USED CAR DEALERS                                 5.639648   15.164833
# USED CAR DEALERS                                 1.539291   21.393250
# TAXI SERVICE                                    24.576371    4.922376
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES         84.186316   64.215337
# OFFICE ADMINISTRATIVE SERVICES                  18.225974   37.243807
# MANAGEMENT CONSULTING SERVICES                   5.045947   15.134900
# TAXI & LIMOUSINE SERVICE                         6.467505   14.522827
# ALL OTHER SPECIAL TRADE CONTRACTORS            105.824116   83.949218
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE   24.880866    5.112657
# OTHER MISCELLANEOUS STORE RETAILERS             13.896940    6.167167
# MANAGEMENT CONSULTING SERVICES                   0.689600   19.515062
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        6.028836   16.141025
#
#                                                   ...           fight  \
# ACTIVITY_DESC                                     ...
# REAL ESTATE                                       ...        1.086112
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS        ...        5.373451
# CONSULTING SERVICES                               ...       23.846683
# PHOTOGRAPHIC SERVICES                             ...       20.199030
# OTHER SPECIAL TRADE CONTRACTORS                   ...       15.805736
# FULL-SERVICE RESTAURANTS                          ...        3.738455
# OTHER PERSONAL SERVICES                           ...       24.030013
# GRAPHIC DESIGN SERVICES                           ...       38.918911
# MARKETING CONSULTING SERVICES                     ...        3.670357
# OTHER SERVICES TO BUILDINGS & DWELLINGS           ...        3.422705
# FULL-SERVICE RESTAURANTS                          ...        3.748895
# CONSULTING SERVICES                               ...       19.194886
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS         ...        5.043153
# REPAIR & MAINTENANCE                              ...        4.943233
# ALL OTHER SPECIAL TRADE CONTRACTORS               ...       30.995052
# RETAIL SALES VIA INTERNET/WEBSITES                ...       27.178111
# OTHER MISCELLANEOUS STORE RETAILERS               ...        3.064962
# BEAUTY SALONS                                     ...        2.858718
# BUSINESS TAX EXEMPT                               ...       42.364190
# CONSULTING SERVICES                               ...        8.806662
# OTHER SERVICES TO BUILDINGS & DWELLINGS           ...       50.942763
# MASSAGE THERAPY                                   ...        3.955653
# PLUMBING, HEATING & AC CONTRACTOR                 ...       50.591349
# BUILDING, DEVELOPING & GENERAL CONTRACTING        ...      118.355086
# ALL OTHER AUTOMOTIVE R&M                          ...       14.917070
# OTHER SPECIAL TRADE CONTRACTORS                   ...      565.778903
# PLUMBING, HEATING & AC CONTRACTOR                 ...       86.764624
# MANAGEMENT CONSULTING SERVICES                    ...       12.013699
# OTHER SERVICES TO BUILDINGS & DWELLINGS           ...        2.944775
# NONSTORE RETAILERS                                ...        2.442054
# ...                                               ...             ...
# BEAUTY SALONS                                     ...        2.820647
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES     ...        9.431096
# USED CAR DEALERS                                  ...        8.953131
# USED CAR DEALERS                                  ...        8.641708
# LEGAL SERVICES                                    ...       21.129779
# CONSULTING SERVICES                               ...        4.368718
# OFFICES OF LAWYERS                                ...        3.685698
# OTHER SERVICES TO BUILDINGS & DWELLINGS           ...        6.529929
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M        ...        9.215605
# BUILDING, DEVELOPING & GENERAL CONTRACTING        ...       39.016389
# BUILDING, DEVELOPING & GENERAL CONTRACTING        ...       16.179213
# JANITORIAL SERVICES                               ...        2.868344
# OTHER PERSONAL SERVICES                           ...        6.378076
# TAXI SERVICE                                      ...       29.937332
# CONSULTING SERVICES                               ...       18.190607
# BEAUTY SHOPS - BOOTH RENTAL                       ...       29.825324
# ALL OTHER PERSONAL SERVICES                       ...        1.610198
# OTHER PERSONAL SERVICES                           ...        3.687002
# USED CAR DEALERS                                  ...        1.318027
# USED CAR DEALERS                                  ...        5.757513
# TAXI SERVICE                                      ...       20.030060
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES           ...       79.822458
# OFFICE ADMINISTRATIVE SERVICES                    ...       21.883830
# MANAGEMENT CONSULTING SERVICES                    ...        0.582970
# TAXI & LIMOUSINE SERVICE                          ...        2.041207
# ALL OTHER SPECIAL TRADE CONTRACTORS               ...      101.210611
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE     ...       20.478498
# OTHER MISCELLANEOUS STORE RETAILERS               ...        9.615695
# MANAGEMENT CONSULTING SERVICES                    ...        4.183634
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS         ...        2.702304
#
#                                                     alcoh       alcoh  \
# ACTIVITY_DESC
# REAL ESTATE                                      0.578970    5.694998
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       5.812214   11.385597
# CONSULTING SERVICES                             23.492377   18.200743
# PHOTOGRAPHIC SERVICES                           19.933703   15.185885
# OTHER SPECIAL TRADE CONTRACTORS                 15.490546   10.564990
# FULL-SERVICE RESTAURANTS                         3.215725    5.498550
# OTHER PERSONAL SERVICES                         23.709970   18.614894
# GRAPHIC DESIGN SERVICES                         38.607900   33.477532
# MARKETING CONSULTING SERVICES                    3.253742    2.834241
# OTHER SERVICES TO BUILDINGS & DWELLINGS          3.439221    4.895215
# FULL-SERVICE RESTAURANTS                         3.900477    9.205271
# CONSULTING SERVICES                             18.889348   13.940469
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        4.683792    2.289767
# REPAIR & MAINTENANCE                             4.514653    1.854327
# ALL OTHER SPECIAL TRADE CONTRACTORS             30.730804   25.861513
# RETAIL SALES VIA INTERNET/WEBSITES              26.913568   22.074071
# OTHER MISCELLANEOUS STORE RETAILERS              3.106948    8.254385
# BEAUTY SALONS                                    2.289386    4.953534
# BUSINESS TAX EXEMPT                             42.101827   37.183274
# CONSULTING SERVICES                              8.478088    4.020301
# OTHER SERVICES TO BUILDINGS & DWELLINGS         50.622095   45.408300
# MASSAGE THERAPY                                  3.566083    2.702152
# PLUMBING, HEATING & AC CONTRACTOR               50.255800   44.954867
# BUILDING, DEVELOPING & GENERAL CONTRACTING     117.951611  111.970698
# ALL OTHER AUTOMOTIVE R&M                        14.546725    9.300078
# OTHER SPECIAL TRADE CONTRACTORS                565.189254  556.289937
# PLUMBING, HEATING & AC CONTRACTOR               86.468436   81.346371
# MANAGEMENT CONSULTING SERVICES                  11.651678    6.577391
# OTHER SERVICES TO BUILDINGS & DWELLINGS          3.045051    5.320714
# NONSTORE RETAILERS                               2.963952    8.496319
# ...                                                   ...         ...
# BEAUTY SALONS                                    2.351555    3.522939
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    9.091654    4.432420
# USED CAR DEALERS                                 9.062666    8.023543
# USED CAR DEALERS                                 8.293529    3.704699
# LEGAL SERVICES                                  21.507181   26.885898
# CONSULTING SERVICES                              3.857396    2.073952
# OFFICES OF LAWYERS                               3.809324    9.057892
# OTHER SERVICES TO BUILDINGS & DWELLINGS          6.474808    5.084810
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       8.881812    4.303409
# BUILDING, DEVELOPING & GENERAL CONTRACTING      38.744192   33.798935
# BUILDING, DEVELOPING & GENERAL CONTRACTING      15.829699   10.682066
# JANITORIAL SERVICES                              3.415034    8.239438
# OTHER PERSONAL SERVICES                          6.008339    2.148110
# TAXI SERVICE                                    29.644448   24.647469
# CONSULTING SERVICES                             17.904394   13.085830
# BEAUTY SHOPS - BOOTH RENTAL                     29.557185   24.678993
# ALL OTHER PERSONAL SERVICES                      1.998850    6.366506
# OTHER PERSONAL SERVICES                          3.899044    9.329637
# USED CAR DEALERS                                 1.695772    6.238266
# USED CAR DEALERS                                 6.015611   11.432688
# TAXI SERVICE                                    19.806512   15.274612
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES         79.538885   74.478104
# OFFICE ADMINISTRATIVE SERVICES                  22.256684   27.634475
# MANAGEMENT CONSULTING SERVICES                   0.441476    5.650374
# TAXI & LIMOUSINE SERVICE                         2.305758    5.972701
# ALL OTHER SPECIAL TRADE CONTRACTORS            100.794833   94.738545
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE   20.204738   15.407149
# OTHER MISCELLANEOUS STORE RETAILERS              9.282495    4.645355
# MANAGEMENT CONSULTING SERVICES                   4.291689    9.446918
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        3.214452    7.701774
#
#                                                     fight       alcoh  \
# ACTIVITY_DESC
# REAL ESTATE                                      4.162429    0.415001
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       3.699126    5.677815
# CONSULTING SERVICES                             27.710089   23.699656
# PHOTOGRAPHIC SERVICES                           24.298959   20.167853
# OTHER SPECIAL TRADE CONTRACTORS                 19.771031   15.709580
# FULL-SERVICE RESTAURANTS                         4.780570    3.065087
# OTHER PERSONAL SERVICES                         27.971224   23.926654
# GRAPHIC DESIGN SERVICES                         42.876119   38.826700
# MARKETING CONSULTING SERVICES                    7.473018    3.446253
# OTHER SERVICES TO BUILDINGS & DWELLINGS          7.806098    3.725155
# FULL-SERVICE RESTAURANTS                         0.488077    3.654451
# CONSULTING SERVICES                             23.179746   19.110818
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        8.962618    4.895033
# REPAIR & MAINTENANCE                             8.665343    4.698090
# ALL OTHER SPECIAL TRADE CONTRACTORS             35.096232   30.964710
# RETAIL SALES VIA INTERNET/WEBSITES              31.278494   27.147504
# OTHER MISCELLANEOUS STORE RETAILERS              1.377650    2.845888
# BEAUTY SALONS                                    4.825573    2.185792
# BUSINESS TAX EXEMPT                             46.474473   42.336322
# CONSULTING SERVICES                             12.763916    8.695370
# OTHER SERVICES TO BUILDINGS & DWELLINGS         54.882227   50.838589
# MASSAGE THERAPY                                  7.822651    3.768914
# PLUMBING, HEATING & AC CONTRACTOR               54.511455   50.469269
# BUILDING, DEVELOPING & GENERAL CONTRACTING     122.550408  118.173985
# ALL OTHER AUTOMOTIVE R&M                        18.739997   14.748838
# OTHER SPECIAL TRADE CONTRACTORS                572.565370  565.546090
# PLUMBING, HEATING & AC CONTRACTOR               90.751528   86.690846
# MANAGEMENT CONSULTING SERVICES                  15.864170   11.856620
# OTHER SERVICES TO BUILDINGS & DWELLINGS          7.306065    3.329396
# NONSTORE RETAILERS                               3.710038    2.912738
# ...                                                   ...         ...
# BEAUTY SALONS                                    6.511178    2.522405
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES   13.355397    9.304962
# USED CAR DEALERS                                13.593224    9.373587
# USED CAR DEALERS                                12.547800    8.504367
# LEGAL SERVICES                                  17.904046   21.333889
# CONSULTING SERVICES                              7.789482    3.996392
# OFFICES OF LAWYERS                               0.572890    3.558408
# OTHER SERVICES TO BUILDINGS & DWELLINGS         10.973786    6.760085
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M      13.156383    9.097115
# BUILDING, DEVELOPING & GENERAL CONTRACTING      43.087826   38.975048
# BUILDING, DEVELOPING & GENERAL CONTRACTING      20.054095   16.038150
# JANITORIAL SERVICES                              5.523313    3.513376
# OTHER PERSONAL SERVICES                         10.248116    6.213564
# TAXI SERVICE                                    33.946181   29.868858
# CONSULTING SERVICES                             22.230873   18.132061
# BEAUTY SHOPS - BOOTH RENTAL                     33.912830   29.789756
# ALL OTHER PERSONAL SERVICES                      5.665752    2.219423
# OTHER PERSONAL SERVICES                          0.770059    3.666800
# USED CAR DEALERS                                 5.440182    1.916634
# USED CAR DEALERS                                 1.941715    5.791395
# TAXI SERVICE                                    24.267072   20.055015
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES         83.846891   79.765164
# OFFICE ADMINISTRATIVE SERVICES                  18.600746   22.080085
# MANAGEMENT CONSULTING SERVICES                   4.767674    0.712329
# TAXI & LIMOUSINE SERVICE                         6.269492    2.564855
# ALL OTHER SPECIAL TRADE CONTRACTORS            105.397668  101.015282
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE   24.552470   20.436088
# OTHER MISCELLANEOUS STORE RETAILERS             13.555591    9.497767
# MANAGEMENT CONSULTING SERVICES                   0.303009    4.037652
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        5.936287    3.366203
#
#                                                     fight       fight  \
# ACTIVITY_DESC
# REAL ESTATE                                      4.988487    4.044222
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS      10.167443    3.723401
# CONSULTING SERVICES                             18.832248   27.591206
# PHOTOGRAPHIC SERVICES                           15.181891   24.180212
# OTHER SPECIAL TRADE CONTRACTORS                 10.815904   19.652517
# FULL-SERVICE RESTAURANTS                         6.051518    4.677454
# OTHER PERSONAL SERVICES                         19.027283   27.852677
# GRAPHIC DESIGN SERVICES                         33.907130   42.757549
# MARKETING CONSULTING SERVICES                    1.960919    7.354529
# OTHER SERVICES TO BUILDINGS & DWELLINGS          2.237037    7.694008
# FULL-SERVICE RESTAURANTS                         8.648595    0.381669
# CONSULTING SERVICES                             14.196319   23.061228
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        1.024859    8.844188
# REPAIR & MAINTENANCE                             1.623781    8.546845
# ALL OTHER SPECIAL TRADE CONTRACTORS             25.972991   34.977266
# RETAIL SALES VIA INTERNET/WEBSITES              22.157757   31.159598
# OTHER MISCELLANEOUS STORE RETAILERS              7.798509    1.260575
# BEAUTY SALONS                                    5.143575    4.712112
# BUSINESS TAX EXEMPT                             37.335157   46.355265
# CONSULTING SERVICES                              3.879317   12.645430
# OTHER SERVICES TO BUILDINGS & DWELLINGS         45.914538   54.763374
# MASSAGE THERAPY                                  1.621370    7.704213
# PLUMBING, HEATING & AC CONTRACTOR               45.539568   54.392100
# BUILDING, DEVELOPING & GENERAL CONTRACTING     112.840578  122.419080
# ALL OTHER AUTOMOTIVE R&M                         9.959012   18.621349
# OTHER SPECIAL TRADE CONTRACTORS                557.427359  572.352039
# PLUMBING, HEATING & AC CONTRACTOR               81.752811   90.632994
# MANAGEMENT CONSULTING SERVICES                   7.084064   15.745619
# OTHER SERVICES TO BUILDINGS & DWELLINGS          2.858136    7.196175
# NONSTORE RETAILERS                               7.085181    3.638235
# ...                                                   ...         ...
# BEAUTY SALONS                                    2.812544    6.392670
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    4.510832   13.236886
# USED CAR DEALERS                                 5.015010   13.481334
# USED CAR DEALERS                                 3.759601   12.429284
# LEGAL SERVICES                                  25.903810   18.005809
# CONSULTING SERVICES                              2.477473    7.671484
# OFFICES OF LAWYERS                               8.545021    0.454423
# OTHER SERVICES TO BUILDINGS & DWELLINGS          2.094112   10.858917
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       4.289556   13.037881
# BUILDING, DEVELOPING & GENERAL CONTRACTING      33.999519   42.968971
# BUILDING, DEVELOPING & GENERAL CONTRACTING      11.201758   19.935502
# JANITORIAL SERVICES                              6.327775    5.445420
# OTHER PERSONAL SERVICES                          1.783120   10.129601
# TAXI SERVICE                                    24.931237   33.827634
# CONSULTING SERVICES                             13.185373   22.112305
# BEAUTY SHOPS - BOOTH RENTAL                     24.807066   33.793966
# ALL OTHER PERSONAL SERVICES                      4.486626    5.562295
# OTHER PERSONAL SERVICES                          8.656618    0.713640
# USED CAR DEALERS                                 4.476863    5.334690
# USED CAR DEALERS                                10.761569    2.046433
# TAXI SERVICE                                    14.977565   24.147685
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES         74.811689   83.728261
# OFFICE ADMINISTRATIVE SERVICES                  26.677936   18.704045
# MANAGEMENT CONSULTING SERVICES                   4.463912    4.652938
# TAXI & LIMOUSINE SERVICE                         3.894882    6.163408
# ALL OTHER SPECIAL TRADE CONTRACTORS             95.667077  105.265792
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE   15.466314   24.433799
# OTHER MISCELLANEOUS STORE RETAILERS              4.681592   13.437086
# MANAGEMENT CONSULTING SERVICES                   9.009085    0.269980
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        5.660232    5.849590
#
#                                                     fight       alcoh  \
# ACTIVITY_DESC
# REAL ESTATE                                      5.770857    4.052822
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       4.438470    3.719108
# CONSULTING SERVICES                             29.190462   27.600259
# PHOTOGRAPHIC SERVICES                           25.902502   24.188819
# OTHER SPECIAL TRADE CONTRACTORS                 21.317265   19.661305
# FULL-SERVICE RESTAURANTS                         5.859740    4.686553
# OTHER PERSONAL SERVICES                         29.492491   27.861546
# GRAPHIC DESIGN SERVICES                         44.394145   42.766422
# MARKETING CONSULTING SERVICES                    9.040351    7.363290
# OTHER SERVICES TO BUILDINGS & DWELLINGS          9.559537    7.701256
# FULL-SERVICE RESTAURANTS                         2.173330    0.388136
# CONSULTING SERVICES                             24.729264   23.070000
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS       10.542082    8.852880
# REPAIR & MAINTENANCE                            10.188969    8.555769
# ALL OTHER SPECIAL TRADE CONTRACTORS             36.693285   34.985915
# RETAIL SALES VIA INTERNET/WEBSITES              32.877175   31.168236
# OTHER MISCELLANEOUS STORE RETAILERS              2.924079    1.269714
# BEAUTY SALONS                                    6.142348    4.721427
# BUSINESS TAX EXEMPT                             48.071782   46.363939
# CONSULTING SERVICES                             14.329344   12.654163
# OTHER SERVICES TO BUILDINGS & DWELLINGS         56.383804   54.772331
# MASSAGE THERAPY                                  9.401203    7.712919
# PLUMBING, HEATING & AC CONTRACTOR               55.999247   54.401164
# BUILDING, DEVELOPING & GENERAL CONTRACTING     124.114697  122.429292
# ALL OTHER AUTOMOTIVE R&M                        20.223017   18.630384
# OTHER SPECIAL TRADE CONTRACTORS                575.179981  572.368430
# PLUMBING, HEATING & AC CONTRACTOR               92.275679   90.641831
# MANAGEMENT CONSULTING SERVICES                  17.371137   15.754565
# OTHER SERVICES TO BUILDINGS & DWELLINGS          9.066671    7.203130
# NONSTORE RETAILERS                               5.318236    3.641357
# ...                                                   ...         ...
# BEAUTY SALONS                                    8.074344    6.401463
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES   14.904848   13.245680
# USED CAR DEALERS                                15.489902   13.488060
# USED CAR DEALERS                                14.094482   12.438093
# LEGAL SERVICES                                  16.922144   17.997331
# CONSULTING SERVICES                              9.248102    7.680621
# OFFICES OF LAWYERS                               2.218716    0.463174
# OTHER SERVICES TO BUILDINGS & DWELLINGS         12.746528   10.866439
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M      14.713381   13.046647
# BUILDING, DEVELOPING & GENERAL CONTRACTING      44.666699   42.977668
# BUILDING, DEVELOPING & GENERAL CONTRACTING      21.557193   19.944454
# JANITORIAL SERVICES                              7.177527    5.449051
# OTHER PERSONAL SERVICES                         11.798740   10.138407
# TAXI SERVICE                                    35.497236   33.836394
# CONSULTING SERVICES                             23.808289   22.120984
# BEAUTY SHOPS - BOOTH RENTAL                     35.503705   33.802625
# ALL OTHER PERSONAL SERVICES                      7.414108    5.568520
# OTHER PERSONAL SERVICES                          2.379994    0.715042
# USED CAR DEALERS                                 7.184272    5.341169
# USED CAR DEALERS                                 1.656194    2.037500
# TAXI SERVICE                                    25.934966   24.156140
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES         85.393167   83.737035
# OFFICE ADMINISTRATIVE SERVICES                  17.579541   18.695503
# MANAGEMENT CONSULTING SERVICES                   6.458834    4.660738
# TAXI & LIMOUSINE SERVICE                         8.025477    6.169920
# ALL OTHER SPECIAL TRADE CONTRACTORS            106.954516  105.276095
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE   26.143368   24.442441
# OTHER MISCELLANEOUS STORE RETAILERS             15.110333   13.445858
# MANAGEMENT CONSULTING SERVICES                   1.714115    0.273276
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        7.642317    5.854034
#
#                                                     fight
# ACTIVITY_DESC
# REAL ESTATE                                      4.897985
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       1.293105
# CONSULTING SERVICES                             28.210782
# PHOTOGRAPHIC SERVICES                           24.355233
# OTHER SPECIAL TRADE CONTRACTORS                 20.071095
# FULL-SERVICE RESTAURANTS                         6.769066
# OTHER PERSONAL SERVICES                         28.303012
# GRAPHIC DESIGN SERVICES                         43.166699
# MARKETING CONSULTING SERVICES                    8.022014
# OTHER SERVICES TO BUILDINGS & DWELLINGS          7.236239
# FULL-SERVICE RESTAURANTS                         2.535606
# CONSULTING SERVICES                             23.436372
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        9.375609
# REPAIR & MAINTENANCE                             9.316581
# ALL OTHER SPECIAL TRADE CONTRACTORS             35.136656
# RETAIL SALES VIA INTERNET/WEBSITES              31.323459
# OTHER MISCELLANEOUS STORE RETAILERS              3.251891
# BEAUTY SALONS                                    6.381159
# BUSINESS TAX EXEMPT                             46.497519
# CONSULTING SERVICES                             13.103528
# OTHER SERVICES TO BUILDINGS & DWELLINGS         55.223821
# MASSAGE THERAPY                                  8.301749
# PLUMBING, HEATING & AC CONTRACTOR               54.927901
# BUILDING, DEVELOPING & GENERAL CONTRACTING     123.222776
# ALL OTHER AUTOMOTIVE R&M                        19.296063
# OTHER SPECIAL TRADE CONTRACTORS                573.417934
# PLUMBING, HEATING & AC CONTRACTOR               90.964002
# MANAGEMENT CONSULTING SERVICES                  16.367295
# OTHER SERVICES TO BUILDINGS & DWELLINGS          6.619362
# NONSTORE RETAILERS                               2.199787
# ...                                                   ...
# BEAUTY SALONS                                    7.151064
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES   13.743918
# USED CAR DEALERS                                12.235335
# USED CAR DEALERS                                12.966908
# LEGAL SERVICES                                  16.974166
# CONSULTING SERVICES                              8.720150
# OFFICES OF LAWYERS                               2.739398
# OTHER SERVICES TO BUILDINGS & DWELLINGS         10.342380
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M      13.519912
# BUILDING, DEVELOPING & GENERAL CONTRACTING      43.168449
# BUILDING, DEVELOPING & GENERAL CONTRACTING      20.517117
# JANITORIAL SERVICES                              3.739740
# OTHER PERSONAL SERVICES                         10.724006
# TAXI SERVICE                                    34.140645
# CONSULTING SERVICES                             22.392604
# BEAUTY SHOPS - BOOTH RENTAL                     33.975245
# ALL OTHER PERSONAL SERVICES                      4.833002
# OTHER PERSONAL SERVICES                          2.069849
# USED CAR DEALERS                                 4.762693
# USED CAR DEALERS                                 2.352398
# TAXI SERVICE                                    24.110889
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES         83.987991
# OFFICE ADMINISTRATIVE SERVICES                  17.718398
# MANAGEMENT CONSULTING SERVICES                   4.891372
# TAXI & LIMOUSINE SERVICE                         5.480807
# ALL OTHER SPECIAL TRADE CONTRACTORS            106.128657
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE   24.650985
# OTHER MISCELLANEOUS STORE RETAILERS             13.918859
# MANAGEMENT CONSULTING SERVICES                   2.940180
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        4.351950
#
# [26058 rows x 2597 columns]

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# # Analysis 1: Using 3 Closest Police Stops
# ## 1. Basic idea
# Police stops are not uniformly distributed, therefore we determine these stops to be reflected by the businesses around the stop and the type of business. Since we believe that physical altercations and drunken behavior that lead to police stops, happen more often around businesses that provide alcohol we will want to investigate **alcohol, drugs and fights** and its connection to **3 nearset shops**.

# %%
traffic_df = pd.read_csv("traffic_crime.csv")
traffic_df = traffic_df.set_index("stop_id")
business_df = pd.read_csv("business_clean_df.csv")
reasonable_df = pd.read_csv("reasonable_crime.csv")
reasonable_df = reasonable_df.set_index("stop_id")
business_df = business_df[["ACTIVITY DESC", "lon", "lat"]]

# %%
def getDistanceTo(lon1, lat1, lon2, lat2) :
    coords_1 = (lat1, lon1)
    coords_2 = (lat2, lon2)
    return geopy.distance.distance(coords_1, coords_2).miles

# %% [markdown]
# ## 2. Approach to finding closest businesses
# `def closest_3_business(lon, lat)` is a function that takes a point as an input, output 3 cloest shops types, as well as its distance.
#
# 1. **filter out** alcohol crime stops from `reasonable_df`
# 2. find 3 **cloest shops** for all the data
# 3. **sum up** the count for every kind of shops
# 4. **eliminate the offset**: divide all the counts by the number of shops in San Diego
# 5. **compare the final value** that reflect the correation between business types and alcochol crimes
# 6. execute same process on **Drug data** and **fight**
#
#
# ### 2.2 Implementation Note `def closest_3_business(lon, lat)`
# It is very time consuming to obtain distance based on latitude and longitude because this does not produce a Euclidean distance and both latitude & longitude are not straight lines.
# Based on this, we used a threshold to judge whether this point is likely to be a closest point or not. This method reduces the computing time by ruling out about 99% of points, with the help of tuple calculation, pushes the speed of one iteration from **7 second** to **20 ms**

# %%
def substitute(li, newPair):
    for i in range(3):
        if li[i][1] > newPair[1]:
            li[i] = newPair
            break
    return li

import math
def closest_3_business(lon, lat, threshold=0.003):
    li = [('-', 10000000), ('-', 10000000), ('-', 10000000)]
    hit = 0
    lon = float(lon)
    lat = float(lat)
    for row in business_df.itertuples():
        lon2 = row[2]
        lat2 = row[3]
        if abs(lon - lon2) > threshold or abs(lat - lat2) > threshold:
            continue
        else:
            distance = getDistanceTo(lon1=lon, lat1=lat, lon2=lon2, lat2=lat2)
            hit += 1
            # biggest index
            biggest_index = 0
            for i in range(3):
                if li[i][1] > li[biggest_index][1]:
                    biggest_index = i

            # modify the list
            if distance < li[biggest_index][1]:
                li[biggest_index] = (row[1], distance)
    
    if ('-', 10000000) in  li:
        return closest_3_business(lon, lat, threshold+0.1)
                
#     print(hit)
    return li

def insert_adapter(business1, business2, business3, distance1, distance2, distance3, target):
    # ready to insert into dataframe
    business1.append(target[0][0])
    business2.append(target[1][0])
    business3.append(target[2][0])
    distance1.append(target[0][1])
    distance2.append(target[1][1])
    distance3.append(target[2][1])

# %%
reasonable_df['crime_type'].value_counts()

# %% [markdown]
# # 3. Alcohol Related Stops
# ### Obtaining all police stops related to alcohol

# %%
alcohol_df = reasonable_df[reasonable_df['crime_type']=='*alcohol*']
alcohol_df.head(3)

# %% [markdown]
# ### Obtain distances between businesses and alcohol related police stops

# %%
# this block may take 3 min
business1 = []
business2 = []
business3 = []
distance1 = []
distance2 = []
distance3 = []

tmp = 0
for row in alcohol_df.itertuples():
    target = closest_3_business(row[2], row[3])
    insert_adapter(business1, business2, business3, distance1, distance2, distance3, target)

# %%
alcohol_df.loc[:,'busi_1'] = business1
alcohol_df.loc[:,'busi_2'] = business2
alcohol_df.loc[:,'busi_3'] = business3
alcohol_df.loc[:,'distance_1'] = distance1
alcohol_df.loc[:,'distance_2'] = distance2
alcohol_df.loc[:,'distance_3'] = distance3

# %%
alcohol_near_business = pd.DataFrame()
alcohol_near_business['ACTIVITY DESC'] = pd.Series(business1+business2+business3).value_counts().index
alcohol_near_business['counts'] = pd.Series(business1+business2+business3).value_counts().tolist()
alcohol_near_business[:10]

# %% [markdown]
# ### 4. Offset Step
# An offset is implemented in order to assign a correct weight to each calculations. For example there are 2657 construction sites in San Diego, while there are only 6 data processing centers. There is no double that construction site appears more often near the crime only because they have more pin on the map. Because our analysis is on the type of business that affect the crime, not the number of sites, this offset step is necessary

# %%
# business_df.value_counts()
busi_value_counts = pd.DataFrame()
busi_value_counts['ACTIVITY DESC'] = business_df['ACTIVITY DESC'].value_counts().index
busi_value_counts['counts'] = business_df['ACTIVITY DESC'].value_counts().tolist()
busi_value_counts.head(10).T

# %%
li = []
for row in alcohol_near_business.itertuples():
    busi_type = row[1]
    near_count = row[2]
    busi_amount = busi_value_counts[busi_value_counts['ACTIVITY DESC'] == busi_type].iloc[0,1]
    li.append(near_count/busi_amount)
alcohol_near_business['offsetted_count'] = li
alcohol_near_business.sort_values(by='offsetted_count', inplace=True, ascending=False)
alcohol_near_business = alcohol_near_business[alcohol_near_business['counts']>20]
alcohol_near_business[:10]

# %%
numbers_shown = 10

plt.figure(figsize=(11,5))

plt.barh(y=[i for i in range(1,numbers_shown+1)],
        height=0.5,
        width=alcohol_near_business['offsetted_count'][:numbers_shown],
        tick_label=alcohol_near_business['ACTIVITY DESC'][:numbers_shown],
        color='pink',
        edgecolor='blue')

plt.title('Most influential business types on ALCOHOL');

# %% [markdown]
# # 5. Drug Related Stops
# ### Obtaining all police stops related to drugs

# %%
drug_df = reasonable_df[reasonable_df['crime_type'] == '*drugs*']
# this block may take 3 min
business1 = []
business2 = []
business3 = []
distance1 = []
distance2 = []
distance3 = []

tmp = 0
for row in drug_df.itertuples():
    target = closest_3_business(row[2], row[3])
    insert_adapter(business1, business2, business3, distance1, distance2, distance3, target)

# %%
drug_business_total = pd.DataFrame()
drug_business_total['ACTIVITY DESC'] = pd.Series(business1 + business2 + business3).value_counts().index
drug_business_total['counts'] = pd.Series(business1 + business2 + business3).value_counts().tolist()
drug_business_total[:5]

# %%
li = []
for row in drug_business_total.itertuples():
    busi_type = row[1]
    near_count = row[2]
    busi_amount = busi_value_counts[busi_value_counts['ACTIVITY DESC'] == busi_type].iloc[0,1]
    li.append(near_count/busi_amount)
drug_business_total['offsetted_count'] = li
drug_business_total.sort_values(by='offsetted_count', inplace=True, ascending=False)
drug_business_total = drug_business_total[drug_business_total['counts']>20]
drug_business_total[:10]

# %%
numbers_shown = 10

plt.figure(figsize=(11,5))

plt.barh(y=[i for i in range(1,numbers_shown+1)],
        height=0.5,
        width=drug_business_total['offsetted_count'][:numbers_shown],
        tick_label=drug_business_total['ACTIVITY DESC'][:numbers_shown],
        color='cyan',
        edgecolor='blue');

plt.title('Most influential business types on DRUGS');

# %% [markdown]
# # 6. Fight/Battery Related Stops
# ### Obtaining all police stops related to physical altercations

# %%
fight_df = reasonable_df[reasonable_df['crime_type'] == '*fight / battery*']
# this block may take 3 min
business1 = []
business2 = []
business3 = []
distance1 = []
distance2 = []
distance3 = []

tmp = 0
for row in fight_df.itertuples():
    target = closest_3_business(row[2], row[3])
    insert_adapter(business1, business2, business3, distance1, distance2, distance3, target)

# %%
fight_business_total = pd.DataFrame()
fight_business_total['ACTIVITY DESC'] = pd.Series(business1 + business2 + business3).value_counts().index
fight_business_total['counts'] = pd.Series(business1 + business2 + business3).value_counts().tolist()
fight_business_total[:5]

# %%
li = []
for row in fight_business_total.itertuples():
    busi_type = row[1]
    near_count = row[2]
    busi_amount = busi_value_counts[busi_value_counts['ACTIVITY DESC'] == busi_type].iloc[0,1]
    li.append(near_count/busi_amount)
fight_business_total['offsetted_count'] = li
fight_business_total.sort_values(by='offsetted_count', inplace=True, ascending=False)
fight_business_total = fight_business_total[fight_business_total['counts']>20]
fight_business_total[:10]

# %%
numbers_shown = 10

plt.figure(figsize=(11,5))

plt.barh(y=[i for i in range(1,numbers_shown+1)],
        height=0.5,
        width=fight_business_total['offsetted_count'][:numbers_shown],
        tick_label=fight_business_total['ACTIVITY DESC'][:numbers_shown],
        color='yellow',
        edgecolor='blue');

plt.title('Most influential business types on fight / battery');

# %% [markdown]
# # Analysis 2: ANOVA Modeling

# %% [markdown]
# We start by finding out how many police stops occured within 500 meter of each business establishment.

# %% [markdown]
# The following cell converts each distance value to nan if greater than 0.5 and 1 if lesser

# %%
maxDistance = 0.5 #km
floor_df = maxDistance / business_df

floor_df = np.floor(floor_df)
floor_df = floor_df / floor_df
floor_df
# Out:
#                                                fight  fight  alcoh  fight  \
# ACTIVITY_DESC
# REAL ESTATE                                      NaN    NaN    NaN    NaN
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# PHOTOGRAPHIC SERVICES                            NaN    NaN    NaN    NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN    NaN    NaN    NaN
# FULL-SERVICE RESTAURANTS                         NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# GRAPHIC DESIGN SERVICES                          NaN    NaN    NaN    NaN
# MARKETING CONSULTING SERVICES                    NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# FULL-SERVICE RESTAURANTS                         NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN    NaN    NaN    NaN
# REPAIR & MAINTENANCE                             NaN    NaN    NaN    NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN    NaN    NaN    NaN
# RETAIL SALES VIA INTERNET/WEBSITES               NaN    NaN    NaN    NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN    NaN    NaN    NaN
# BEAUTY SALONS                                    NaN    NaN    NaN    NaN
# BUSINESS TAX EXEMPT                              NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# MASSAGE THERAPY                                  NaN    NaN    NaN    NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# ALL OTHER AUTOMOTIVE R&M                         NaN    NaN    NaN    NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN    NaN    NaN    NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# NONSTORE RETAILERS                               NaN    NaN    NaN    NaN
# ...                                              ...    ...    ...    ...
# BEAUTY SALONS                                    NaN    NaN    NaN    NaN
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# LEGAL SERVICES                                   NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# OFFICES OF LAWYERS                               NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# JANITORIAL SERVICES                              NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# TAXI SERVICE                                     NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# BEAUTY SHOPS - BOOTH RENTAL                      NaN    NaN    NaN    NaN
# ALL OTHER PERSONAL SERVICES                      NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# TAXI SERVICE                                     NaN    NaN    NaN    NaN
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES          NaN    NaN    NaN    NaN
# OFFICE ADMINISTRATIVE SERVICES                   NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN    NaN    NaN
# TAXI & LIMOUSINE SERVICE                         NaN    NaN    NaN    NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN    NaN    NaN    NaN
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE    NaN    NaN    NaN    NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN    NaN    1.0
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN    NaN    NaN    NaN
#
#                                                alcoh  fight  alcoh  fight  \
# ACTIVITY_DESC
# REAL ESTATE                                      NaN    1.0    NaN    NaN
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# PHOTOGRAPHIC SERVICES                            NaN    NaN    NaN    NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN    NaN    NaN    NaN
# FULL-SERVICE RESTAURANTS                         NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# GRAPHIC DESIGN SERVICES                          NaN    NaN    NaN    NaN
# MARKETING CONSULTING SERVICES                    NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# FULL-SERVICE RESTAURANTS                         NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN    NaN    NaN    NaN
# REPAIR & MAINTENANCE                             NaN    NaN    NaN    NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN    NaN    NaN    NaN
# RETAIL SALES VIA INTERNET/WEBSITES               NaN    NaN    NaN    NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN    NaN    NaN    NaN
# BEAUTY SALONS                                    NaN    NaN    NaN    NaN
# BUSINESS TAX EXEMPT                              NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# MASSAGE THERAPY                                  NaN    NaN    NaN    NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# ALL OTHER AUTOMOTIVE R&M                         NaN    NaN    NaN    NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN    NaN    NaN    NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# NONSTORE RETAILERS                               NaN    NaN    NaN    NaN
# ...                                              ...    ...    ...    ...
# BEAUTY SALONS                                    NaN    NaN    NaN    NaN
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# LEGAL SERVICES                                   NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# OFFICES OF LAWYERS                               NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# JANITORIAL SERVICES                              NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# TAXI SERVICE                                     NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# BEAUTY SHOPS - BOOTH RENTAL                      NaN    NaN    NaN    NaN
# ALL OTHER PERSONAL SERVICES                      NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# TAXI SERVICE                                     NaN    NaN    NaN    NaN
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES          NaN    NaN    NaN    NaN
# OFFICE ADMINISTRATIVE SERVICES                   NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN    NaN    NaN
# TAXI & LIMOUSINE SERVICE                         NaN    NaN    NaN    NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN    NaN    NaN    NaN
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE    NaN    NaN    NaN    NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN    NaN    NaN
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN    NaN    NaN    NaN
#
#                                                fight  fight  ...    fight  \
# ACTIVITY_DESC                                                ...
# REAL ESTATE                                      NaN    NaN  ...      NaN
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       NaN    NaN  ...      NaN
# CONSULTING SERVICES                              NaN    NaN  ...      NaN
# PHOTOGRAPHIC SERVICES                            NaN    NaN  ...      NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN    NaN  ...      NaN
# FULL-SERVICE RESTAURANTS                         NaN    NaN  ...      NaN
# OTHER PERSONAL SERVICES                          NaN    NaN  ...      NaN
# GRAPHIC DESIGN SERVICES                          NaN    NaN  ...      NaN
# MARKETING CONSULTING SERVICES                    NaN    NaN  ...      NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN  ...      NaN
# FULL-SERVICE RESTAURANTS                         NaN    NaN  ...      NaN
# CONSULTING SERVICES                              NaN    NaN  ...      NaN
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN    NaN  ...      NaN
# REPAIR & MAINTENANCE                             NaN    NaN  ...      NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN    NaN  ...      NaN
# RETAIL SALES VIA INTERNET/WEBSITES               NaN    NaN  ...      NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN    NaN  ...      NaN
# BEAUTY SALONS                                    NaN    NaN  ...      NaN
# BUSINESS TAX EXEMPT                              NaN    NaN  ...      NaN
# CONSULTING SERVICES                              NaN    NaN  ...      NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN  ...      NaN
# MASSAGE THERAPY                                  NaN    NaN  ...      NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN    NaN  ...      NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN  ...      NaN
# ALL OTHER AUTOMOTIVE R&M                         NaN    NaN  ...      NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN    NaN  ...      NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN    NaN  ...      NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN  ...      NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN  ...      NaN
# NONSTORE RETAILERS                               NaN    NaN  ...      NaN
# ...                                              ...    ...  ...      ...
# BEAUTY SALONS                                    NaN    NaN  ...      NaN
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    NaN    NaN  ...      NaN
# USED CAR DEALERS                                 NaN    NaN  ...      NaN
# USED CAR DEALERS                                 NaN    NaN  ...      NaN
# LEGAL SERVICES                                   NaN    NaN  ...      NaN
# CONSULTING SERVICES                              NaN    NaN  ...      NaN
# OFFICES OF LAWYERS                               NaN    NaN  ...      NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN  ...      NaN
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       NaN    NaN  ...      NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN  ...      NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN  ...      NaN
# JANITORIAL SERVICES                              NaN    NaN  ...      NaN
# OTHER PERSONAL SERVICES                          NaN    NaN  ...      NaN
# TAXI SERVICE                                     NaN    NaN  ...      NaN
# CONSULTING SERVICES                              NaN    NaN  ...      NaN
# BEAUTY SHOPS - BOOTH RENTAL                      NaN    NaN  ...      NaN
# ALL OTHER PERSONAL SERVICES                      NaN    NaN  ...      NaN
# OTHER PERSONAL SERVICES                          NaN    NaN  ...      NaN
# USED CAR DEALERS                                 NaN    NaN  ...      NaN
# USED CAR DEALERS                                 NaN    NaN  ...      NaN
# TAXI SERVICE                                     NaN    NaN  ...      NaN
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES          NaN    NaN  ...      NaN
# OFFICE ADMINISTRATIVE SERVICES                   NaN    NaN  ...      NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN  ...      NaN
# TAXI & LIMOUSINE SERVICE                         NaN    NaN  ...      NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN    NaN  ...      NaN
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE    NaN    NaN  ...      NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN    NaN  ...      NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN  ...      NaN
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN    NaN  ...      NaN
#
#                                                alcoh  alcoh  fight  alcoh  \
# ACTIVITY_DESC
# REAL ESTATE                                      NaN    NaN    NaN    1.0
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# PHOTOGRAPHIC SERVICES                            NaN    NaN    NaN    NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN    NaN    NaN    NaN
# FULL-SERVICE RESTAURANTS                         NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# GRAPHIC DESIGN SERVICES                          NaN    NaN    NaN    NaN
# MARKETING CONSULTING SERVICES                    NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# FULL-SERVICE RESTAURANTS                         NaN    NaN    1.0    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN    NaN    NaN    NaN
# REPAIR & MAINTENANCE                             NaN    NaN    NaN    NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN    NaN    NaN    NaN
# RETAIL SALES VIA INTERNET/WEBSITES               NaN    NaN    NaN    NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN    NaN    NaN    NaN
# BEAUTY SALONS                                    NaN    NaN    NaN    NaN
# BUSINESS TAX EXEMPT                              NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# MASSAGE THERAPY                                  NaN    NaN    NaN    NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# ALL OTHER AUTOMOTIVE R&M                         NaN    NaN    NaN    NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN    NaN    NaN    NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# NONSTORE RETAILERS                               NaN    NaN    NaN    NaN
# ...                                              ...    ...    ...    ...
# BEAUTY SALONS                                    NaN    NaN    NaN    NaN
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# LEGAL SERVICES                                   NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# OFFICES OF LAWYERS                               NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# JANITORIAL SERVICES                              NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# TAXI SERVICE                                     NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# BEAUTY SHOPS - BOOTH RENTAL                      NaN    NaN    NaN    NaN
# ALL OTHER PERSONAL SERVICES                      NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# TAXI SERVICE                                     NaN    NaN    NaN    NaN
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES          NaN    NaN    NaN    NaN
# OFFICE ADMINISTRATIVE SERVICES                   NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   1.0    NaN    NaN    NaN
# TAXI & LIMOUSINE SERVICE                         NaN    NaN    NaN    NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN    NaN    NaN    NaN
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE    NaN    NaN    NaN    NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN    1.0    NaN
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN    NaN    NaN    NaN
#
#                                                fight  fight  fight  alcoh  \
# ACTIVITY_DESC
# REAL ESTATE                                      NaN    NaN    NaN    NaN
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# PHOTOGRAPHIC SERVICES                            NaN    NaN    NaN    NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN    NaN    NaN    NaN
# FULL-SERVICE RESTAURANTS                         NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# GRAPHIC DESIGN SERVICES                          NaN    NaN    NaN    NaN
# MARKETING CONSULTING SERVICES                    NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# FULL-SERVICE RESTAURANTS                         NaN    1.0    NaN    1.0
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN    NaN    NaN    NaN
# REPAIR & MAINTENANCE                             NaN    NaN    NaN    NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN    NaN    NaN    NaN
# RETAIL SALES VIA INTERNET/WEBSITES               NaN    NaN    NaN    NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN    NaN    NaN    NaN
# BEAUTY SALONS                                    NaN    NaN    NaN    NaN
# BUSINESS TAX EXEMPT                              NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# MASSAGE THERAPY                                  NaN    NaN    NaN    NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# ALL OTHER AUTOMOTIVE R&M                         NaN    NaN    NaN    NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN    NaN    NaN    NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN    NaN    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# NONSTORE RETAILERS                               NaN    NaN    NaN    NaN
# ...                                              ...    ...    ...    ...
# BEAUTY SALONS                                    NaN    NaN    NaN    NaN
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# LEGAL SERVICES                                   NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# OFFICES OF LAWYERS                               NaN    1.0    NaN    1.0
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN    NaN    NaN    NaN
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN    NaN    NaN    NaN
# JANITORIAL SERVICES                              NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# TAXI SERVICE                                     NaN    NaN    NaN    NaN
# CONSULTING SERVICES                              NaN    NaN    NaN    NaN
# BEAUTY SHOPS - BOOTH RENTAL                      NaN    NaN    NaN    NaN
# ALL OTHER PERSONAL SERVICES                      NaN    NaN    NaN    NaN
# OTHER PERSONAL SERVICES                          NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# USED CAR DEALERS                                 NaN    NaN    NaN    NaN
# TAXI SERVICE                                     NaN    NaN    NaN    NaN
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES          NaN    NaN    NaN    NaN
# OFFICE ADMINISTRATIVE SERVICES                   NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    NaN    NaN    NaN
# TAXI & LIMOUSINE SERVICE                         NaN    NaN    NaN    NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN    NaN    NaN    NaN
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE    NaN    NaN    NaN    NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN    NaN    NaN    NaN
# MANAGEMENT CONSULTING SERVICES                   NaN    1.0    NaN    1.0
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN    NaN    NaN    NaN
#
#                                                fight
# ACTIVITY_DESC
# REAL ESTATE                                      NaN
# ALL OTHER TRANSIT & GROUND PASSENGER TRANS       NaN
# CONSULTING SERVICES                              NaN
# PHOTOGRAPHIC SERVICES                            NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN
# FULL-SERVICE RESTAURANTS                         NaN
# OTHER PERSONAL SERVICES                          NaN
# GRAPHIC DESIGN SERVICES                          NaN
# MARKETING CONSULTING SERVICES                    NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN
# FULL-SERVICE RESTAURANTS                         NaN
# CONSULTING SERVICES                              NaN
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN
# REPAIR & MAINTENANCE                             NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN
# RETAIL SALES VIA INTERNET/WEBSITES               NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN
# BEAUTY SALONS                                    NaN
# BUSINESS TAX EXEMPT                              NaN
# CONSULTING SERVICES                              NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN
# MASSAGE THERAPY                                  NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN
# ALL OTHER AUTOMOTIVE R&M                         NaN
# OTHER SPECIAL TRADE CONTRACTORS                  NaN
# PLUMBING, HEATING & AC CONTRACTOR                NaN
# MANAGEMENT CONSULTING SERVICES                   NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN
# NONSTORE RETAILERS                               NaN
# ...                                              ...
# BEAUTY SALONS                                    NaN
# ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES    NaN
# USED CAR DEALERS                                 NaN
# USED CAR DEALERS                                 NaN
# LEGAL SERVICES                                   NaN
# CONSULTING SERVICES                              NaN
# OFFICES OF LAWYERS                               NaN
# OTHER SERVICES TO BUILDINGS & DWELLINGS          NaN
# OTHER ELECTRONIC & PRECISION EQUIPMENT R&M       NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN
# BUILDING, DEVELOPING & GENERAL CONTRACTING       NaN
# JANITORIAL SERVICES                              NaN
# OTHER PERSONAL SERVICES                          NaN
# TAXI SERVICE                                     NaN
# CONSULTING SERVICES                              NaN
# BEAUTY SHOPS - BOOTH RENTAL                      NaN
# ALL OTHER PERSONAL SERVICES                      NaN
# OTHER PERSONAL SERVICES                          NaN
# USED CAR DEALERS                                 NaN
# USED CAR DEALERS                                 NaN
# TAXI SERVICE                                     NaN
# ELECTRONIC SHOPPING & MAIL-ORDER HOUSES          NaN
# OFFICE ADMINISTRATIVE SERVICES                   NaN
# MANAGEMENT CONSULTING SERVICES                   NaN
# TAXI & LIMOUSINE SERVICE                         NaN
# ALL OTHER SPECIAL TRADE CONTRACTORS              NaN
# OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE    NaN
# OTHER MISCELLANEOUS STORE RETAILERS              NaN
# MANAGEMENT CONSULTING SERVICES                   NaN
# INDEPENDENT ARTISTS, WRITERS & PERFORMERS        NaN
#
# [26058 rows x 2597 columns]

# %% [markdown]
# We then split our data by crime type and add up all the columns.
# That gives us the total number of police stops for each business establishment

# %%
fight_df = floor_df.filter(like='fight')
alcoh_df = floor_df.filter(like='alcoh')

# %%
fight_df["number_of_crimes_in_area"] = fight_df.sum(axis=1)
alcoh_df["number_of_crimes_in_area"] = alcoh_df.sum(axis=1)
# Out:
# C:\Users\Tamuz\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Tamuz\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
alcoh_df = alcoh_df[["number_of_crimes_in_area"]]
fight_df = fight_df[["number_of_crimes_in_area"]]

# %%
fight_df = fight_df.reset_index()
alcoh_df = alcoh_df.reset_index()
fight_df.head()
# Out:
#    index                                  ACTIVITY_DESC  \
# 0  23806  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES
# 1  19173  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES
# 2  22123  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES
# 3  17897  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES
# 4  24750  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES
#
#    number_of_crimes_in_area
# 0                      10.0
# 1                      39.0
# 2                      16.0
# 3                       0.0
# 4                       8.0

# %%
alcoh_df.head()
# Out:
#    index                                  ACTIVITY_DESC  \
# 0  23806  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES
# 1  23658  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES
# 2  20015  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES
# 3   7630  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES
# 4  20004  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES
#
#    number_of_crimes_in_area
# 0                       9.0
# 1                       0.0
# 2                       1.0
# 3                       6.0
# 4                       2.0

# %% [markdown]
# We now run our model which is a one way ANOVA with 101 groups encompassing each business type.

# %%
fight_results = ols('number_of_crimes_in_area ~ C(ACTIVITY_DESC)', data=fight_df).fit()
alcoh_results = ols('number_of_crimes_in_area ~ C(ACTIVITY_DESC)', data=alcoh_df).fit()

# %% [markdown]
# The next two cells have the sum of the ANOVA test. As we had over 100 diffrent groups it is quite long. We should instead
# foucus on the big picture in the next section.

# %%
fight_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     number_of_crimes_in_area   R-squared:                       0.078
# Model:                                  OLS   Adj. R-squared:                  0.074
# Method:                       Least Squares   F-statistic:                     21.83
# Date:                      Wed, 12 Jun 2019   Prob (F-statistic):               0.00
# Time:                              23:22:14   Log-Likelihood:            -1.0381e+05
# No. Observations:                     26058   AIC:                         2.078e+05
# Df Residuals:                         25957   BIC:                         2.087e+05
# Df Model:                               100
# Covariance Type:                  nonrobust
# =====================================================================================================================================
#                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                             9.7081      0.677     14.336      0.000       8.381      11.035
# C(ACTIVITY_DESC)[T.ACTIVITIES RELATED TO REAL ESTATE]                 2.6328      1.193      2.207      0.027       0.295       4.971
# C(ACTIVITY_DESC)[T.ADVERTISING & RELATED SERVICES]                    1.8339      1.430      1.283      0.200      -0.969       4.636
# C(ACTIVITY_DESC)[T.ALL OTH PROF, SCIENTIFIC & TECHNICAL SERVICES]    -1.6260      0.787     -2.067      0.039      -3.168      -0.084
# C(ACTIVITY_DESC)[T.ALL OTHER AUTOMOTIVE R&M]                          1.3457      1.328      1.013      0.311      -1.257       3.949
# C(ACTIVITY_DESC)[T.ALL OTHER GENERAL MERCHANDISE STORES]              0.5322      1.249      0.426      0.670      -1.916       2.981
# C(ACTIVITY_DESC)[T.ALL OTHER MISCELLANEOUS STORE RETAILERS]           1.8391      1.435      1.282      0.200      -0.974       4.652
# C(ACTIVITY_DESC)[T.ALL OTHER PERSONAL SERVICES]                       0.7580      0.822      0.922      0.357      -0.853       2.369
# C(ACTIVITY_DESC)[T.ALL OTHER SPECIAL TRADE CONTRACTORS]              -7.1622      0.874     -8.192      0.000      -8.876      -5.449
# C(ACTIVITY_DESC)[T.ALL OTHER TRANSIT & GROUND PASSENGER TRANS]       -1.0103      1.296     -0.780      0.436      -3.550       1.530
# C(ACTIVITY_DESC)[T.ARCHITECTURAL SERVICES]                            2.1056      1.457      1.445      0.148      -0.750       4.961
# C(ACTIVITY_DESC)[T.ARCHITECTURAL, ENGINEERING & RELATED SERVICES]     1.1571      1.188      0.974      0.330      -1.172       3.486
# C(ACTIVITY_DESC)[T.AUTOMOTIVE R&M]                                    1.6957      1.243      1.364      0.173      -0.742       4.133
# C(ACTIVITY_DESC)[T.BARBER SHOPS]                                      7.5152      1.451      5.179      0.000       4.671      10.360
# C(ACTIVITY_DESC)[T.BEAUTY SALONS]                                     6.0034      0.857      7.009      0.000       4.325       7.682
# C(ACTIVITY_DESC)[T.BEAUTY SHOPS - BOOTH RENTAL]                       6.2948      0.972      6.476      0.000       4.390       8.200
# C(ACTIVITY_DESC)[T.BEER, WINE & LIQUOR STORES]                        3.8017      1.457      2.610      0.009       0.946       6.657
# C(ACTIVITY_DESC)[T.BUILDING, DEVELOPING & GENERAL CONTRACTING]       -5.5858      0.840     -6.650      0.000      -7.232      -3.939
# C(ACTIVITY_DESC)[T.BUSINESS TAX EXEMPT]                               2.0738      1.167      1.778      0.075      -0.213       4.361
# C(ACTIVITY_DESC)[T.BUSINESS TAX EXEMPT - NON PROFIT]                  3.1235      1.021      3.060      0.002       1.123       5.124
# C(ACTIVITY_DESC)[T.CHILD DAY CARE SERVICES]                           0.8839      1.348      0.656      0.512      -1.757       3.525
# C(ACTIVITY_DESC)[T.CIVIC & SOCIAL ORGANIZATIONS]                      3.9304      1.120      3.508      0.000       1.734       6.126
# C(ACTIVITY_DESC)[T.COMPUTER SYSTEMS DESIGN & RELATED SERVICES]       -1.2211      1.005     -1.215      0.224      -3.190       0.748
# C(ACTIVITY_DESC)[T.CONSTRUCTION]                                     -3.6714      1.420     -2.586      0.010      -6.454      -0.889
# C(ACTIVITY_DESC)[T.CONSULTING SERVICES]                               0.0761      0.840      0.091      0.928      -1.571       1.723
# C(ACTIVITY_DESC)[T.DIRECT SELLING ESTABLISHMENTS]                    -1.6933      1.310     -1.293      0.196      -4.260       0.874
# C(ACTIVITY_DESC)[T.EDUCATIONAL SERVICES]                             -0.3537      1.132     -0.312      0.755      -2.573       1.866
# C(ACTIVITY_DESC)[T.EDUCATIONAL SUPPORT SERVICES]                     -0.1456      1.193     -0.122      0.903      -2.483       2.192
# C(ACTIVITY_DESC)[T.ELECTRICAL CONTRACTORS]                           -6.4484      0.982     -6.564      0.000      -8.374      -4.523
# C(ACTIVITY_DESC)[T.ELECTRONIC SHOPPING & MAIL-ORDER HOUSES]          -0.3569      1.212     -0.295      0.768      -2.732       2.018
# C(ACTIVITY_DESC)[T.ENGINEERING SERVICES]                             -1.9087      0.968     -1.971      0.049      -3.807      -0.010
# C(ACTIVITY_DESC)[T.EXAM PREPARATION & TUTORING]                      -2.1589      1.360     -1.588      0.112      -4.824       0.507
# C(ACTIVITY_DESC)[T.FOOD SERVICES & DRINKING PLACES]                   4.9101      1.078      4.554      0.000       2.797       7.024
# C(ACTIVITY_DESC)[T.FULL-SERVICE RESTAURANTS]                          7.8066      0.858      9.095      0.000       6.124       9.489
# C(ACTIVITY_DESC)[T.GENERAL AUTOMOTIVE REPAIR]                         3.0933      1.289      2.399      0.016       0.566       5.620
# C(ACTIVITY_DESC)[T.GRAPHIC DESIGN SERVICES]                           1.7767      1.321      1.345      0.179      -0.812       4.365
# C(ACTIVITY_DESC)[T.GROCERY STORES]                                    5.9131      1.321      4.478      0.000       3.325       8.502
# C(ACTIVITY_DESC)[T.HAIR, NAIL & SKIN CARE SERVICES]                   5.3781      1.197      4.492      0.000       3.031       7.725
# C(ACTIVITY_DESC)[T.INDEPENDENT ARTISTS, WRITERS & PERFORMERS]         0.5550      0.903      0.615      0.539      -1.215       2.325
# C(ACTIVITY_DESC)[T.INDIVIDUAL & FAMILY SERVICES]                     -0.8273      1.258     -0.658      0.511      -3.293       1.638
# C(ACTIVITY_DESC)[T.INSURANCE AGENCIES & BROKERAGES]                   1.1726      1.420      0.826      0.409      -1.610       3.955
# C(ACTIVITY_DESC)[T.INTERIOR DESIGN SERVICES]                          0.4070      1.296      0.314      0.753      -2.133       2.947
# C(ACTIVITY_DESC)[T.JANITORIAL SERVICES]                               0.1466      0.781      0.188      0.851      -1.384       1.677
# C(ACTIVITY_DESC)[T.LANDSCAPING SERVICES]                             -1.5511      0.932     -1.664      0.096      -3.378       0.275
# C(ACTIVITY_DESC)[T.LEGAL SERVICES]                                   10.0862      0.930     10.848      0.000       8.264      11.909
# C(ACTIVITY_DESC)[T.LIMITED-SERVICE EATING PLACES]                     4.7846      1.036      4.618      0.000       2.754       6.815
# C(ACTIVITY_DESC)[T.LIMITED-SERVICE RESTAURANTS]                       4.9400      1.089      4.535      0.000       2.805       7.075
# C(ACTIVITY_DESC)[T.MANAGEMENT CONSULTING SERVICES]                   -2.2766      0.920     -2.475      0.013      -4.079      -0.474
# C(ACTIVITY_DESC)[T.MANAGEMENT OF COMPANIES & ENTERPRISES]            -0.0546      1.462     -0.037      0.970      -2.921       2.812
# C(ACTIVITY_DESC)[T.MANAGEMENT, SCI & TECH CONSULTING SERVICES]       -2.5921      1.182     -2.194      0.028      -4.908      -0.276
# C(ACTIVITY_DESC)[T.MARKETING CONSULTING SERVICES]                     0.6323      1.289      0.490      0.624      -1.895       3.159
# C(ACTIVITY_DESC)[T.MASSAGE THERAPY]                                   2.1223      1.205      1.762      0.078      -0.239       4.483
# C(ACTIVITY_DESC)[T.MISCELLANEOUS STORE RETAILERS]                     2.8512      1.377      2.070      0.038       0.152       5.551
# C(ACTIVITY_DESC)[T.MOBILE FOOD SERVICES]                              1.9648      1.235      1.591      0.112      -0.456       4.386
# C(ACTIVITY_DESC)[T.NONSTORE RETAILERS]                                0.2123      0.999      0.212      0.832      -1.747       2.171
# C(ACTIVITY_DESC)[T.OFFICE ADMINISTRATIVE SERVICES]                   -1.3364      1.400     -0.955      0.340      -4.081       1.408
# C(ACTIVITY_DESC)[T.OFFICES OF ALL OTH MISC HEALTH PRACTITIONERS]      1.6802      1.004      1.674      0.094      -0.287       3.648
# C(ACTIVITY_DESC)[T.OFFICES OF CHIROPRACTORS]                          1.2439      1.348      0.923      0.356      -1.397       3.885
# C(ACTIVITY_DESC)[T.OFFICES OF DENTISTS]                               2.8750      0.931      3.087      0.002       1.049       4.701
# C(ACTIVITY_DESC)[T.OFFICES OF LAWYERS]                               12.8165      1.028     12.472      0.000      10.802      14.831
# C(ACTIVITY_DESC)[T.OFFICES OF OTHER MENTAL HEALTH PRACTITIONERS]     -1.6403      1.377     -1.191      0.234      -4.340       1.059
# C(ACTIVITY_DESC)[T.OFFICES OF PHYSICIANS]                             1.1860      0.979      1.212      0.226      -0.732       3.104
# C(ACTIVITY_DESC)[T.OFFICES OF PT/OT/SPEECH THERAPY & AUDIOLOGY]      -1.3557      1.440     -0.941      0.347      -4.179       1.467
# C(ACTIVITY_DESC)[T.OFFICES OF REAL ESTATE AGENTS & BROKERS]           0.7076      0.976      0.725      0.468      -1.205       2.620
# C(ACTIVITY_DESC)[T.OTH PROFESSIONAL/SCIENTIFIC/TECHNICAL SERVICE]    -1.5625      0.962     -1.625      0.104      -3.447       0.322
# C(ACTIVITY_DESC)[T.OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE]    -2.1193      1.149     -1.845      0.065      -4.371       0.133
# C(ACTIVITY_DESC)[T.OTHER ACTIVITIES RELATED TO REAL ESTATE]           1.4986      0.966      1.552      0.121      -0.394       3.391
# C(ACTIVITY_DESC)[T.OTHER BUSINESS SERVICES]                           0.5468      1.457      0.375      0.707      -2.309       3.402
# C(ACTIVITY_DESC)[T.OTHER COMPUTER RELATED SERVICES]                  -3.0487      1.299     -2.346      0.019      -5.595      -0.502
# C(ACTIVITY_DESC)[T.OTHER DIRECT SELLING ESTABLISHMENTS]              -2.2990      1.193     -1.927      0.054      -4.637       0.039
# C(ACTIVITY_DESC)[T.OTHER ELECTRONIC & PRECISION EQUIPMENT R&M]       -3.4869      1.400     -2.491      0.013      -6.231      -0.743
# C(ACTIVITY_DESC)[T.OTHER MISCELLANEOUS DURABLE GOODS WHSLE]          -3.3011      1.202     -2.746      0.006      -5.657      -0.945
# C(ACTIVITY_DESC)[T.OTHER MISCELLANEOUS STORE RETAILERS]               0.7829      1.033      0.758      0.448      -1.241       2.807
# C(ACTIVITY_DESC)[T.OTHER PERSONAL & HOUSEHOLD GOODS R&M]              0.5442      1.119      0.486      0.627      -1.648       2.737
# C(ACTIVITY_DESC)[T.OTHER PERSONAL CARE SERVICES]                      3.1490      1.195      2.635      0.008       0.807       5.491
# C(ACTIVITY_DESC)[T.OTHER PERSONAL SERVICES]                           0.2053      0.858      0.239      0.811      -1.476       1.887
# C(ACTIVITY_DESC)[T.OTHER SERVICES TO BUILDINGS & DWELLINGS]          -0.5326      0.914     -0.583      0.560      -2.324       1.259
# C(ACTIVITY_DESC)[T.OTHER SPECIAL TRADE CONTRACTORS]                  -6.3929      1.175     -5.441      0.000      -8.696      -4.090
# C(ACTIVITY_DESC)[T.PAINTING & WALL COVERING CONTRACTORS]             -4.5117      1.405     -3.212      0.001      -7.265      -1.758
# C(ACTIVITY_DESC)[T.PERSONAL FITNESS TRAINER]                          2.7641      1.425      1.940      0.052      -0.028       5.557
# C(ACTIVITY_DESC)[T.PET CARE (EXCEPT VETERINARY) SERVICES]             1.1732      1.377      0.852      0.394      -1.526       3.873
# C(ACTIVITY_DESC)[T.PHOTOGRAPHIC SERVICES]                            -0.6175      1.004     -0.615      0.538      -2.585       1.350
# C(ACTIVITY_DESC)[T.PLUMBING, HEATING & AC CONTRACTOR]                -5.7413      0.963     -5.962      0.000      -7.629      -3.854
# C(ACTIVITY_DESC)[T.PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES]    -1.7064      0.864     -1.976      0.048      -3.399      -0.014
# C(ACTIVITY_DESC)[T.REAL ESTATE]                                       2.0716      1.377      1.504      0.133      -0.628       4.771
# C(ACTIVITY_DESC)[T.REAL ESTATE PROPERTY MANAGERS]                     2.0714      1.340      1.546      0.122      -0.554       4.697
# C(ACTIVITY_DESC)[T.REPAIR & MAINTENANCE]                             -1.1367      1.344     -0.846      0.398      -3.770       1.497
# C(ACTIVITY_DESC)[T.RESIDENTIAL BUILDING CONSTRUCTION]                -4.0014      1.129     -3.545      0.000      -6.214      -1.789
# C(ACTIVITY_DESC)[T.RETAIL SALES VIA INTERNET/WEBSITES]                0.3836      0.989      0.388      0.698      -1.554       2.321
# C(ACTIVITY_DESC)[T.SCIENTIFIC R&D SERVICES]                          -5.4966      1.446     -3.802      0.000      -8.330      -2.663
# C(ACTIVITY_DESC)[T.SERVICES TO BUILDINGS & DWELLINGS]                -2.0493      1.207     -1.698      0.090      -4.415       0.316
# C(ACTIVITY_DESC)[T.SNACK & NONALCOHOLIC BEVERAGE BARS]                7.5033      1.356      5.534      0.000       4.846      10.161
# C(ACTIVITY_DESC)[T.SPECIAL TRADE CONTRACTORS]                        -6.8441      1.097     -6.240      0.000      -8.994      -4.694
# C(ACTIVITY_DESC)[T.SPORTS & RECREATION INSTRUCTION]                  -0.3541      1.400     -0.253      0.800      -3.098       2.390
# C(ACTIVITY_DESC)[T.SWAP MEET VENDOR]                                  8.3010      1.109      7.485      0.000       6.127      10.475
# C(ACTIVITY_DESC)[T.TAX PREPARATION SERVICES]                          0.9415      1.303      0.723      0.470      -1.612       3.495
# C(ACTIVITY_DESC)[T.TAXI & LIMOUSINE SERVICE]                          1.2408      1.303      0.952      0.341      -1.313       3.794
# C(ACTIVITY_DESC)[T.TAXI SERVICE]                                      3.7402      0.936      3.995      0.000       1.905       5.575
# C(ACTIVITY_DESC)[T.USED CAR DEALERS]                                  0.3437      1.065      0.323      0.747      -1.744       2.431
# C(ACTIVITY_DESC)[T.WHOLESALE TRADE, DURABLE GOODS]                   -2.3832      1.149     -2.074      0.038      -4.635      -0.131
# C(ACTIVITY_DESC)[T.WHOLESALE TRADE, NONDURABLE GOODS]                -0.9655      1.462     -0.660      0.509      -3.832       1.901
# ==============================================================================
# Omnibus:                    13970.625   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           101953.099
# Skew:                           2.533   Prob(JB):                         0.00
# Kurtosis:                      11.260   Cond. No.                         85.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
alcoh_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     number_of_crimes_in_area   R-squared:                       0.061
# Model:                                  OLS   Adj. R-squared:                  0.058
# Method:                       Least Squares   F-statistic:                     16.97
# Date:                      Wed, 12 Jun 2019   Prob (F-statistic):          2.92e-278
# Time:                              23:06:16   Log-Likelihood:            -1.0636e+05
# No. Observations:                     26058   AIC:                         2.129e+05
# Df Residuals:                         25957   BIC:                         2.137e+05
# Df Model:                               100
# Covariance Type:                  nonrobust
# =====================================================================================================================================
#                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                             8.8568      0.747     11.861      0.000       7.393      10.320
# C(ACTIVITY_DESC)[T.ACTIVITIES RELATED TO REAL ESTATE]                 2.3251      1.315      1.768      0.077      -0.253       4.903
# C(ACTIVITY_DESC)[T.ADVERTISING & RELATED SERVICES]                    1.8255      1.577      1.158      0.247      -1.265       4.916
# C(ACTIVITY_DESC)[T.ALL OTH PROF, SCIENTIFIC & TECHNICAL SERVICES]    -1.8898      0.867     -2.179      0.029      -3.590      -0.190
# C(ACTIVITY_DESC)[T.ALL OTHER AUTOMOTIVE R&M]                          3.0279      1.464      2.068      0.039       0.157       5.898
# C(ACTIVITY_DESC)[T.ALL OTHER GENERAL MERCHANDISE STORES]              0.8445      1.377      0.613      0.540      -1.855       3.544
# C(ACTIVITY_DESC)[T.ALL OTHER MISCELLANEOUS STORE RETAILERS]           2.7565      1.582      1.742      0.082      -0.345       5.858
# C(ACTIVITY_DESC)[T.ALL OTHER PERSONAL SERVICES]                       0.3686      0.907      0.407      0.684      -1.408       2.145
# C(ACTIVITY_DESC)[T.ALL OTHER SPECIAL TRADE CONTRACTORS]              -6.6351      0.964     -6.883      0.000      -8.525      -4.746
# C(ACTIVITY_DESC)[T.ALL OTHER TRANSIT & GROUND PASSENGER TRANS]       -1.7416      1.429     -1.219      0.223      -4.542       1.059
# C(ACTIVITY_DESC)[T.ARCHITECTURAL SERVICES]                            2.0942      1.606      1.304      0.192      -1.054       5.243
# C(ACTIVITY_DESC)[T.ARCHITECTURAL, ENGINEERING & RELATED SERVICES]     0.5927      1.310      0.452      0.651      -1.975       3.161
# C(ACTIVITY_DESC)[T.AUTOMOTIVE R&M]                                    2.5086      1.371      1.830      0.067      -0.179       5.196
# C(ACTIVITY_DESC)[T.BARBER SHOPS]                                      8.0559      1.600      5.034      0.000       4.919      11.192
# C(ACTIVITY_DESC)[T.BEAUTY SALONS]                                     6.2000      0.944      6.565      0.000       4.349       8.051
# C(ACTIVITY_DESC)[T.BEAUTY SHOPS - BOOTH RENTAL]                       6.2951      1.072      5.873      0.000       4.194       8.396
# C(ACTIVITY_DESC)[T.BEER, WINE & LIQUOR STORES]                        3.7903      1.606      2.360      0.018       0.642       6.939
# C(ACTIVITY_DESC)[T.BUILDING, DEVELOPING & GENERAL CONTRACTING]       -5.2076      0.926     -5.622      0.000      -7.023      -3.392
# C(ACTIVITY_DESC)[T.BUSINESS TAX EXEMPT]                               1.3135      1.286      1.021      0.307      -1.208       3.835
# C(ACTIVITY_DESC)[T.BUSINESS TAX EXEMPT - NON PROFIT]                  3.6347      1.125      3.230      0.001       1.429       5.841
# C(ACTIVITY_DESC)[T.CHILD DAY CARE SERVICES]                          -1.0648      1.486     -0.717      0.474      -3.977       1.848
# C(ACTIVITY_DESC)[T.CIVIC & SOCIAL ORGANIZATIONS]                      4.1010      1.235      3.320      0.001       1.680       6.522
# C(ACTIVITY_DESC)[T.COMPUTER SYSTEMS DESIGN & RELATED SERVICES]       -1.4184      1.108     -1.280      0.200      -3.590       0.753
# C(ACTIVITY_DESC)[T.CONSTRUCTION]                                     -3.5081      1.565     -2.241      0.025      -6.576      -0.440
# C(ACTIVITY_DESC)[T.CONSULTING SERVICES]                              -0.0885      0.926     -0.096      0.924      -1.904       1.727
# C(ACTIVITY_DESC)[T.DIRECT SELLING ESTABLISHMENTS]                    -1.3605      1.444     -0.942      0.346      -4.191       1.470
# C(ACTIVITY_DESC)[T.EDUCATIONAL SERVICES]                             -0.4636      1.249     -0.371      0.710      -2.911       1.984
# C(ACTIVITY_DESC)[T.EDUCATIONAL SUPPORT SERVICES]                     -0.4874      1.315     -0.371      0.711      -3.065       2.091
# C(ACTIVITY_DESC)[T.ELECTRICAL CONTRACTORS]                           -5.9284      1.083     -5.473      0.000      -8.052      -3.805
# C(ACTIVITY_DESC)[T.ELECTRONIC SHOPPING & MAIL-ORDER HOUSES]          -1.1901      1.336     -0.891      0.373      -3.809       1.429
# C(ACTIVITY_DESC)[T.ENGINEERING SERVICES]                             -1.8116      1.068     -1.696      0.090      -3.905       0.282
# C(ACTIVITY_DESC)[T.EXAM PREPARATION & TUTORING]                      -2.3158      1.500     -1.544      0.123      -5.255       0.623
# C(ACTIVITY_DESC)[T.FOOD SERVICES & DRINKING PLACES]                   5.6702      1.189      4.769      0.000       3.340       8.001
# C(ACTIVITY_DESC)[T.FULL-SERVICE RESTAURANTS]                          8.6449      0.946      9.134      0.000       6.790      10.500
# C(ACTIVITY_DESC)[T.GENERAL AUTOMOTIVE REPAIR]                         2.8099      1.422      1.977      0.048       0.024       5.596
# C(ACTIVITY_DESC)[T.GRAPHIC DESIGN SERVICES]                           2.2114      1.456      1.519      0.129      -0.643       5.066
# C(ACTIVITY_DESC)[T.GROCERY STORES]                                    6.4387      1.456      4.421      0.000       3.584       9.293
# C(ACTIVITY_DESC)[T.HAIR, NAIL & SKIN CARE SERVICES]                   5.6662      1.320      4.291      0.000       3.078       8.254
# C(ACTIVITY_DESC)[T.INDEPENDENT ARTISTS, WRITERS & PERFORMERS]         0.3180      0.996      0.319      0.750      -1.634       2.270
# C(ACTIVITY_DESC)[T.INDIVIDUAL & FAMILY SERVICES]                     -0.4859      1.387     -0.350      0.726      -3.205       2.233
# C(ACTIVITY_DESC)[T.INSURANCE AGENCIES & BROKERAGES]                   0.1157      1.565      0.074      0.941      -2.953       3.184
# C(ACTIVITY_DESC)[T.INTERIOR DESIGN SERVICES]                          0.6540      1.429      0.458      0.647      -2.147       3.455
# C(ACTIVITY_DESC)[T.JANITORIAL SERVICES]                              -0.1883      0.861     -0.219      0.827      -1.876       1.499
# C(ACTIVITY_DESC)[T.LANDSCAPING SERVICES]                             -1.7698      1.028     -1.722      0.085      -3.784       0.244
# C(ACTIVITY_DESC)[T.LEGAL SERVICES]                                    8.3920      1.025      8.185      0.000       6.382      10.402
# C(ACTIVITY_DESC)[T.LIMITED-SERVICE EATING PLACES]                     5.1251      1.142      4.486      0.000       2.886       7.364
# C(ACTIVITY_DESC)[T.LIMITED-SERVICE RESTAURANTS]                       4.8171      1.201      4.010      0.000       2.462       7.172
# C(ACTIVITY_DESC)[T.MANAGEMENT CONSULTING SERVICES]                   -2.6284      1.014     -2.592      0.010      -4.616      -0.641
# C(ACTIVITY_DESC)[T.MANAGEMENT OF COMPANIES & ENTERPRISES]            -0.2231      1.613     -0.138      0.890      -3.384       2.938
# C(ACTIVITY_DESC)[T.MANAGEMENT, SCI & TECH CONSULTING SERVICES]       -2.7186      1.303     -2.087      0.037      -5.272      -0.165
# C(ACTIVITY_DESC)[T.MARKETING CONSULTING SERVICES]                     0.5759      1.422      0.405      0.685      -2.210       3.362
# C(ACTIVITY_DESC)[T.MASSAGE THERAPY]                                   3.0029      1.328      2.261      0.024       0.400       5.606
# C(ACTIVITY_DESC)[T.MISCELLANEOUS STORE RETAILERS]                     2.3636      1.519      1.556      0.120      -0.613       5.340
# C(ACTIVITY_DESC)[T.MOBILE FOOD SERVICES]                              2.9860      1.362      2.192      0.028       0.316       5.656
# C(ACTIVITY_DESC)[T.NONSTORE RETAILERS]                                0.4426      1.102      0.402      0.688      -1.718       2.603
# C(ACTIVITY_DESC)[T.OFFICE ADMINISTRATIVE SERVICES]                   -1.0160      1.544     -0.658      0.510      -4.042       2.010
# C(ACTIVITY_DESC)[T.OFFICES OF ALL OTH MISC HEALTH PRACTITIONERS]      1.8196      1.107      1.644      0.100      -0.350       3.989
# C(ACTIVITY_DESC)[T.OFFICES OF CHIROPRACTORS]                          0.9992      1.486      0.672      0.501      -1.913       3.912
# C(ACTIVITY_DESC)[T.OFFICES OF DENTISTS]                               2.1987      1.027      2.141      0.032       0.186       4.212
# C(ACTIVITY_DESC)[T.OFFICES OF LAWYERS]                               11.4496      1.133     10.104      0.000       9.229      13.671
# C(ACTIVITY_DESC)[T.OFFICES OF OTHER MENTAL HEALTH PRACTITIONERS]     -1.6449      1.519     -1.083      0.279      -4.621       1.332
# C(ACTIVITY_DESC)[T.OFFICES OF PHYSICIANS]                             1.2227      1.079      1.133      0.257      -0.892       3.338
# C(ACTIVITY_DESC)[T.OFFICES OF PT/OT/SPEECH THERAPY & AUDIOLOGY]      -1.9520      1.588     -1.229      0.219      -5.065       1.161
# C(ACTIVITY_DESC)[T.OFFICES OF REAL ESTATE AGENTS & BROKERS]           0.6374      1.076      0.593      0.554      -1.471       2.746
# C(ACTIVITY_DESC)[T.OTH PROFESSIONAL/SCIENTIFIC/TECHNICAL SERVICE]    -1.4309      1.060     -1.349      0.177      -3.509       0.647
# C(ACTIVITY_DESC)[T.OTH SCIENTIFIC & TECHNICAL CONSULTING SERVICE]    -2.7502      1.267     -2.171      0.030      -5.233      -0.267
# C(ACTIVITY_DESC)[T.OTHER ACTIVITIES RELATED TO REAL ESTATE]           1.6823      1.065      1.580      0.114      -0.405       3.770
# C(ACTIVITY_DESC)[T.OTHER BUSINESS SERVICES]                           0.9472      1.606      0.590      0.555      -2.201       4.096
# C(ACTIVITY_DESC)[T.OTHER COMPUTER RELATED SERVICES]                  -3.3785      1.433     -2.358      0.018      -6.187      -0.570
# C(ACTIVITY_DESC)[T.OTHER DIRECT SELLING ESTABLISHMENTS]              -2.5272      1.315     -1.921      0.055      -5.105       0.051
# C(ACTIVITY_DESC)[T.OTHER ELECTRONIC & PRECISION EQUIPMENT R&M]       -4.3169      1.544     -2.796      0.005      -7.343      -1.291
# C(ACTIVITY_DESC)[T.OTHER MISCELLANEOUS DURABLE GOODS WHSLE]          -2.9614      1.326     -2.234      0.025      -5.560      -0.363
# C(ACTIVITY_DESC)[T.OTHER MISCELLANEOUS STORE RETAILERS]               1.1397      1.139      1.001      0.317      -1.093       3.372
# C(ACTIVITY_DESC)[T.OTHER PERSONAL & HOUSEHOLD GOODS R&M]              0.2414      1.234      0.196      0.845      -2.177       2.659
# C(ACTIVITY_DESC)[T.OTHER PERSONAL CARE SERVICES]                      3.4632      1.318      2.628      0.009       0.880       6.046
# C(ACTIVITY_DESC)[T.OTHER PERSONAL SERVICES]                           0.4962      0.946      0.525      0.600      -1.358       2.350
# C(ACTIVITY_DESC)[T.OTHER SERVICES TO BUILDINGS & DWELLINGS]          -0.7901      1.008     -0.784      0.433      -2.766       1.186
# C(ACTIVITY_DESC)[T.OTHER SPECIAL TRADE CONTRACTORS]                  -5.6665      1.296     -4.373      0.000      -8.206      -3.127
# C(ACTIVITY_DESC)[T.PAINTING & WALL COVERING CONTRACTORS]             -4.5889      1.549     -2.962      0.003      -7.625      -1.553
# C(ACTIVITY_DESC)[T.PERSONAL FITNESS TRAINER]                          3.8377      1.571      2.443      0.015       0.758       6.917
# C(ACTIVITY_DESC)[T.PET CARE (EXCEPT VETERINARY) SERVICES]             0.9738      1.519      0.641      0.521      -2.003       3.950
# C(ACTIVITY_DESC)[T.PHOTOGRAPHIC SERVICES]                            -1.1157      1.107     -1.008      0.314      -3.285       1.054
# C(ACTIVITY_DESC)[T.PLUMBING, HEATING & AC CONTRACTOR]                -5.2242      1.062     -4.920      0.000      -7.305      -3.143
# C(ACTIVITY_DESC)[T.PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES]    -1.8161      0.952     -1.907      0.056      -3.683       0.050
# C(ACTIVITY_DESC)[T.REAL ESTATE]                                       2.3890      1.519      1.573      0.116      -0.587       5.365
# C(ACTIVITY_DESC)[T.REAL ESTATE PROPERTY MANAGERS]                     2.2220      1.477      1.504      0.133      -0.673       5.117
# C(ACTIVITY_DESC)[T.REPAIR & MAINTENANCE]                             -1.5314      1.482     -1.034      0.301      -4.435       1.373
# C(ACTIVITY_DESC)[T.RESIDENTIAL BUILDING CONSTRUCTION]                -3.4769      1.245     -2.793      0.005      -5.917      -1.037
# C(ACTIVITY_DESC)[T.RETAIL SALES VIA INTERNET/WEBSITES]                0.6142      1.090      0.563      0.573      -1.523       2.751
# C(ACTIVITY_DESC)[T.SCIENTIFIC R&D SERVICES]                          -5.4818      1.594     -3.439      0.001      -8.606      -2.357
# C(ACTIVITY_DESC)[T.SERVICES TO BUILDINGS & DWELLINGS]                -2.0685      1.331     -1.554      0.120      -4.677       0.540
# C(ACTIVITY_DESC)[T.SNACK & NONALCOHOLIC BEVERAGE BARS]                8.6554      1.495      5.790      0.000       5.725      11.586
# C(ACTIVITY_DESC)[T.SPECIAL TRADE CONTRACTORS]                        -6.3875      1.209     -5.282      0.000      -8.758      -4.017
# C(ACTIVITY_DESC)[T.SPORTS & RECREATION INSTRUCTION]                  -0.5205      1.544     -0.337      0.736      -3.546       2.506
# C(ACTIVITY_DESC)[T.SWAP MEET VENDOR]                                  5.8387      1.223      4.775      0.000       3.442       8.236
# C(ACTIVITY_DESC)[T.TAX PREPARATION SERVICES]                          0.5812      1.437      0.405      0.686      -2.234       3.397
# C(ACTIVITY_DESC)[T.TAXI & LIMOUSINE SERVICE]                          1.0192      1.437      0.709      0.478      -1.796       3.835
# C(ACTIVITY_DESC)[T.TAXI SERVICE]                                      3.2171      1.032      3.116      0.002       1.194       5.241
# C(ACTIVITY_DESC)[T.USED CAR DEALERS]                                  1.4022      1.175      1.194      0.233      -0.900       3.704
# C(ACTIVITY_DESC)[T.WHOLESALE TRADE, DURABLE GOODS]                   -2.0040      1.267     -1.582      0.114      -4.487       0.479
# C(ACTIVITY_DESC)[T.WHOLESALE TRADE, NONDURABLE GOODS]                -0.1934      1.613     -0.120      0.905      -3.354       2.967
# ==============================================================================
# Omnibus:                    17292.920   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           213727.047
# Skew:                           3.116   Prob(JB):                         0.00
# Kurtosis:                      15.570   Cond. No.                         85.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The next few cells generate the big picture statistics.

# %%
aov_table_fight = sm.stats.anova_lm(fight_results, typ=2)
aov_table_alc = sm.stats.anova_lm(alcoh_results, typ=2)

# %% [markdown]
# Here we generate the omega squared which explains to what degree is our dependent varible influenced by the independent one.

# %%
def anova_table(aov):
    aov['mean_sq'] = aov[:]['sum_sq']/aov[:]['df']
    
    aov['eta_sq'] = aov[:-1]['sum_sq']/sum(aov['sum_sq'])
    
    aov['omega_sq'] = (aov[:-1]['sum_sq']-(aov[:-1]['df']*aov['mean_sq'][-1]))/(sum(aov['sum_sq'])+aov['mean_sq'][-1])
    
    cols = ['sum_sq', 'df', 'mean_sq', 'F', 'PR(>F)', 'eta_sq', 'omega_sq']
    aov = aov[cols]
    return aov

# %% [markdown]
# This table represents the summary statistics for ANOVA on alcoholic related data

# %%
print("Alcohol:")
anova_table(aov_table_alc)
# Out:
# Alcohol:
#                         sum_sq       df      mean_sq          F  \
# C(ACTIVITY_DESC)  3.501397e+05    100.0  3501.397174  16.971013
# Residual          5.355353e+06  25957.0   206.316332        NaN
#
#                          PR(>F)    eta_sq  omega_sq
# C(ACTIVITY_DESC)  2.922617e-278  0.061369  0.057751
# Residual                    NaN       NaN       NaN

# %% [markdown]
# The F statistic is 16.97 and the p-value is approximately zero. From this we know we can reject our null hypothesis as it seems that there is a correlation between the business type and alcoholic related stops within 500m of the business. Though it is important to note, that with an omega squared value of 0.057 it seems that business type only affects around 5.7% of the difference in frequency of police stops.

# %%
alcoh_results.diagn
# Out:
# {'jb': 213727.0469142914,
#  'jbpv': 0.0,
#  'skew': 3.115849532801785,
#  'kurtosis': 15.570334542599655,
#  'omni': 17292.920151769322,
#  'omnipv': 0.0,
#  'condno': 85.845187781427313,
#  'mineigval': 3.590527344524991}

# %% [markdown]
# This cell shows our test for ANOVA test assumptions of which we failed two. Those being the Jarque-Bera (JB) and the omnibus test.

# %%
print("Fight:")
anova_table(aov_table_fight)
# Out:
# Fight:
#                         sum_sq       df      mean_sq          F  PR(>F)  \
# C(ACTIVITY_DESC)  3.703989e+05    100.0  3703.988725  21.829494     0.0
# Residual          4.404336e+06  25957.0   169.678173        NaN     NaN
#
#                     eta_sq  omega_sq
# C(ACTIVITY_DESC)  0.077575  0.074018
# Residual               NaN       NaN

# %% [markdown]
# Similar to above due to similar numbers, we can conclude the same result.

# %%
fight_results.diagn
# Out:
# {'jb': 101953.09894359244,
#  'jbpv': 0.0,
#  'skew': 2.533138813384164,
#  'kurtosis': 11.260382087819854,
#  'omni': 13970.625441403527,
#  'omnipv': 0.0,
#  'condno': 85.845187781427313,
#  'mineigval': 3.590527344524991}

# %% [markdown]
# Since our data failed the assumption of homogeneity of variance (omni) we used heteroscedasticity corrected
# coefficient covariance matrix to account for it.

# %%
alc_table = sm.stats.anova_lm(fight_results, typ=1)
alc_table
# Out:
#                        df        sum_sq      mean_sq          F  PR(>F)
# C(ACTIVITY_DESC)    100.0  3.703989e+05  3703.988725  21.829494     0.0
# Residual          25957.0  4.404336e+06   169.678173        NaN     NaN

# %% [markdown]
# As seen above correcting for the homogenity of variance resulted in an even stronger effect. We were unable to correct for the other failed assumption, and we will be forever doomed to statistics to hell.

# %%
fight_df = fight_df.sort_values("ACTIVITY_DESC")
alcoh_df = alcoh_df.sort_values("ACTIVITY_DESC")

# %% [markdown]
# Below are box plots of the models on a selection of data sorted alphabetically.

# %%
plt.figure(dpi=1200)
alcoh_df.iloc[0:int(len(alcoh_df)/5)].boxplot('number_of_crimes_in_area', by='ACTIVITY_DESC', figsize=(16, 10), fontsize=10, rot=60)

# %%
plt.figure(dpi=1200)

fight_df.iloc[0:int(len(fight_df)/5)].boxplot('number_of_crimes_in_area', by='ACTIVITY_DESC', figsize=(16, 10), fontsize=10, rot=60)

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# The dataset was acquired from The San Diego Open Data Portal (SDODP), which is a public database for anyone to use. We did not have to deal with any privacy concern regarding the dataset acquired from SDODP since the data was already anonymized. Nevertheless, we still verified whether the datasets were completely free of sensitive information that could lead to privacy concerns by following the guidelines in the official documentation from the Safe Harbour Method.
#
# The data collected was entered by the San Diego Police Department after conducting a police stop. Therefore, it is probable that the data is directly influenced by the biases inherent of the San Diego Police Department such as what neighborhoods police officers choose to patrol more than others. The analysis conducted must be understood in this context and not be generalized to make claims that are not backed up by the data.
#
# The most important issue we had is the possible confusion of police stops and crimes. Police stops had several inherent biases such as the location police officers choose to patrol and who they choose to stop. Furthermore, the frequency of police stops in an area does not reveal an inherent correlation to crimes in that area. We ensured that this distinction was made clear as to not create unfounded or biased conclusions.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# In our expoloratory analysis we found that there were certain business types that had a significantly larger number of police stops related to alcohol, drugs, and physical altercations. These business types include hotels/motels and parking lots/garages. Although this analysis did not completely support our background research, we still found that bars and other alcohol related business did have some signficance to the type of police stops we were investigating, albiet a smaller significance compared to other business types.
#
# Based on our ANOVA analysis and modeling however, we found that our hypothesis was proven to be true.
# As seen in our ANOVA summaries above the F statistics is significantly greater our F critical value which is close to 0. This means that the probability of certain business types based on the average number of police stops in the area is statistically signficant. In other words, the chance of randomly obtaining a distribution that is the same as our dataset is close to zero. By this fact, we are able to reject the null hypothesis and say that there exists a correlation between the type of business and police stops related with intoxicating substances (drugs and alcohol) and physical altercations.
#
# Due to the nature of the methods we used in our analysis, there were some assumptions that we made in order to come to a conclusion. Some assumptions were used in order to consolidate the business types into certain categories and the removal of certain business types due to the small number of them in San Diego. Because of this, we may have missed some correlations that may have affected our results. Additionally, although our result was statistically significant, due to the low omega square value (degree of association for the independent variable on the dependent variable) the result is not practically signficant
